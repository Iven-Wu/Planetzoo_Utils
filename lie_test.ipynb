# %%
from os import read
import torch
from lietorch import SO3, SE3, LieGroupParameter

import argparse
import numpy as np
import time
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import chamfer3D.dist_chamfer_3D
# import pytorch3d
from pdb import post_mortem, set_trace as bp

import itertools
from torch.autograd import Variable
import random
import torch.nn.functional as FF
from sklearn.cluster import kmeans_plusplus
import open3d as o3d
import os

# %%
def read_obj(obj_path,for_open_mesh=False):
    with open(obj_path) as file:
        flag = 0
        points = []
        normals = []
        faces = []
        while 1:
            line = file.readline()
            if not line:
                break
            strs = line.split(" ")
            if strs[0] =='o' and flag==0:
                flag = 1
                continue
            elif strs[0]=='o' and flag==1:
                break
            if strs[0] =='v':
                points.append((float(strs[1]),float(strs[2]),float(strs[3])))
            
            if strs[0] == 'vn':
                normals.append((float(strs[1]),float(strs[2]),float(strs[3])))
            if strs[0] =='f':
                single_line_face = strs[1:]
                
#                 for sf in single_line_face:
#                     face_index = sf.split('/')
#                     faces.append((int(face_index[0]),int(face_index[1]),int(face_index[2])))
#                     break
                f_co = []
                for sf in single_line_face:
                    face_tmp = sf.split('/')[0]
                    f_co.append(face_tmp)
                if for_open_mesh == False:
                    if len(f_co)==3:
                        faces.append((int(f_co[0]),int(f_co[1]),int(f_co[2])))
                    elif len(f_co)==4:
                        faces.append((int(f_co[0]),int(f_co[1]),int(f_co[2])))
                        faces.append((int(f_co[0]),int(f_co[1]),int(f_co[3])))
                        faces.append((int(f_co[1]),int(f_co[2]),int(f_co[3])))
                        faces.append((int(f_co[0]),int(f_co[3]),int(f_co[2])))
                else:
                    faces.append([int(ver) for ver in f_co])
                
    points = np.array(points)

    normals = np.array(normals)
    faces = np.array(faces)
    return points,normals,faces

# %%
class LaplacianLoss(nn.Module):
    def __init__(self, vertex, faces, average=False):
        super(LaplacianLoss, self).__init__()
        self.nv = vertex.shape[0]
        self.nf = faces.shape[0]
        self.average = average
        laplacian = np.zeros([self.nv, self.nv]).astype(np.float32)

        laplacian[faces[:, 0], faces[:, 1]] = -1
        laplacian[faces[:, 1], faces[:, 0]] = -1
        laplacian[faces[:, 1], faces[:, 2]] = -1
        laplacian[faces[:, 2], faces[:, 1]] = -1
        laplacian[faces[:, 2], faces[:, 0]] = -1
        laplacian[faces[:, 0], faces[:, 2]] = -1

        r, c = np.diag_indices(laplacian.shape[0])
        laplacian[r, c] = -laplacian.sum(1)

        
        for i in range(self.nv):
            if laplacian[i, i]!=0: 
                laplacian[i, :] /= laplacian[i, i]

        self.register_buffer('laplacian', torch.from_numpy(laplacian))

    def forward(self, x):
        batch_size = x.shape[0]
        x = torch.matmul(self.laplacian.cuda(), x)
        dims = tuple(range(x.ndimension())[1:])
        x = x.pow(2).sum(dims)
        if self.average:
            return x.sum() / batch_size
        else:
            return x

# %%
if __name__ == '__main__':
    # parser = argparse.ArgumentParser()
    # parser.add_argument('--old', default='frame_000001.obj')
    # parser.add_argument('--target', default='frame_000002.obj')
    # args = parser.parse_args()

    # output_path = args.problem.replace('.g2o', '_rotavg.g2o')
    # input_pose_graph = read_g2o(args.problem)

    seed = 2000
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    points_info,normals_info,face_info = read_obj('frame_000001.obj')
    old_ones = np.ones((points_info.shape[0],1))
    
    
    points_info = np.concatenate((points_info,old_ones),axis=1)
    all_info_list = []
    for i in range(20, 30):
        path = "frame_{:06d}.obj".format(i+1)

        tmp_target = read_obj(path)[0]
        target_ones = np.ones((tmp_target.shape[0],1))
        tmp_target_new = np.concatenate((tmp_target,target_ones),axis=1)
        all_info_list.append(tmp_target_new)

        
    la_loss = LaplacianLoss(torch.tensor(points_info),torch.tensor(face_info-1),average=True)
    all_info = np.stack(all_info_list)
    old_info = points_info
    target_info = all_info
    # W,R= train(old_info=points_info,target_info=all_info)

    N = points_info.shape[0]
    F = target_info.shape[0]
    B = 40  ### 这个肯定可以通过读pkl得到

    center, indexes = kmeans_plusplus(old_info[:, :-1], n_clusters=B, random_state=0)
    old_mesh = torch.tensor(old_info).float().cuda().detach()
    # bp()
    # ones = torch.ones(old_mesh.shape[0], 1).cuda()
    # x = torch.cat([old_mesh, ones], dim=1)

    center_t = torch.tensor(center).repeat(F, 1, 1).cuda()
    target_mesh = torch.tensor(target_info, requires_grad=False).float().cuda().detach()

    # bp()
    # W = torch.randint(10,(N,B))
    # W = torch.randn((N,B)).cuda()
    # W = np.random.randint(10,size=(N,B))
    # bp()
    # W = SO3(torch.from_numpy(W).float().cuda())
    # W = torch.zeros((N, B), dtype=torch.float, requires_grad=True, device="cuda")
    W = torch.randn((N, B), requires_grad=True, device="cuda")
    W2 = torch.randn((N, B), requires_grad=True, device="cuda")
    # W = torch.tensor(W0.float(), requires_grad=True, device="cuda")
    # W = W * 0
    # bp()
    # W = LieGroupParameter(W)
    # bp()
    # R = torch.randint(10,(B,3,3))

    # bp()pcd.points = Vector3dVector(np_points)
    # random quaternion
   # bounding_box_max = old_mesh.max()
    # bounding_box_min = old_mesh.min()
    p1 = torch.randn((F, B, 7), requires_grad=True, device="cuda")
    # with torch.no_grad():
    #     p1[:, :, 4:] = center_t
    # W = W.cuda()
    # p1 = p1.cuda()
    # p1 = p1 / p1.norm(dim=-1, keepdim=True)
    # create SO3 object from quaternion (differentiable w.r.t q)
    
    # 4x4 transformation matrix (differentiable w.r.t R)
    

    # W = torch.tensor(np.load('weight.npy')).float().cuda()
    optimizer = optim.Adam([W,  p1],lr=1e-2)

    chamLoss = chamfer3D.dist_chamfer_3D.chamfer_3DDist()
    for i in range(10000):
        # if i == 2000:
        #     optimizer = optim.Adam([W, p1],lr=1e-3)
        optimizer.zero_grad()
        loss = 0
        loss2 = 0
        f_idxs = random.sample(range(F), F)
        
        for f in f_idxs:
            T = torch.randn(B, 4, 4)
            W1 = FF.softmax(W * 10)
            W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
            # W3 = FF.softmax(W2)
            # W3 = (W3 / (W3.sum(1, keepdim=True).detach()))
            # dist= W3.unsqueeze(2) * old_mesh.unsqueeze(1).repeat(1, 45, 1)
            # dist = dist.sum(0)
            
            for b in range(B):
                # R = SO3.InitFromVec(p1[f, b])
                # bp()
                # bp()
                # with torch.no_grad():
                # temp = torch.cat([p1[f, b], dist[f][:-1]])
                R = SE3.InitFromVec(p1[f, b])
                # bp()
                T[b] = R.matrix()
            T = T.cuda()     
            # bp()      
            # bp() 
            # W1 = W
            # W1 = (W - W.min()) / (W.max() - W.min())
            
            # bp()
            # p1[:, :, 4:] = 
            # bp()
            # ones = torch.ones(old_mesh.shape[0], 1).cuda()
            # x = torch.cat([old_mesh, ones], dim=1)
            x = old_mesh
        
        
            bx = (T@x.T).permute(2, 0, 1)
            wbx = W1.unsqueeze(2) * bx
            # bp()
            wbx =  wbx.permute((1,0,2))
            # print("Wbx", wbx.shape)
            # wbx = wbx.sum(0, keepdim=True)[:, :, :-1]
            wbx = wbx.sum(0, keepdim=True)
            # loss_init = chamLoss(target_mesh[f][None],wbx)
            # loss += loss_init[0].sum()

#             bp()
            loss += torch.sum((target_mesh[f]-wbx)**2)
            # loss2 += la_loss(W1) * 100
            # loss += torch.sum((target_mesh[f]-wbx)**2) +la_loss(W.detach().cpu())
#             loss.backward()
            # print("loss",loss)
            # bp()
        # bp()
        (loss + loss2).backward()
        # print("this is loss for epoch {} : {} ".format(i,loss.detach().cpu().numpy()))
        print("this is loss for epoch {} : {}, {} ".format(i,loss / F, loss2/F))
        # print("p1: ", p1)
        optimizer.step()


    new_R = SE3.InitFromVec(p1)
    R = new_R.matrix()

    # W1 = (W - W.min()) / (W.max() - W.min())
    # W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
    # bp()
    # return R.detach(), W1.detach()
# Out:
# /home/ivenwu/miniconda3/envs/lietorch/lib/python3.7/site-packages/ipykernel_launcher.py:94: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# this is loss for epoch 0 : 10621.0302734375, 0.0
# this is loss for epoch 1 : 10201.5625, 0.0
# this is loss for epoch 2 : 9797.103515625, 0.0
# this is loss for epoch 3 : 9407.7861328125, 0.0
# this is loss for epoch 4 : 9033.6826171875, 0.0
# this is loss for epoch 5 : 8674.6005859375, 0.0
# this is loss for epoch 6 : 8330.240234375, 0.0
# this is loss for epoch 7 : 8000.20654296875, 0.0
# this is loss for epoch 8 : 7684.0009765625, 0.0
# this is loss for epoch 9 : 7381.02294921875, 0.0
# this is loss for epoch 10 : 7090.6494140625, 0.0
# this is loss for epoch 11 : 6812.24169921875, 0.0
# this is loss for epoch 12 : 6545.09912109375, 0.0
# this is loss for epoch 13 : 6288.43115234375, 0.0
# this is loss for epoch 14 : 6041.42041015625, 0.0
# this is loss for epoch 15 : 5803.32373046875, 0.0
# this is loss for epoch 16 : 5573.54541015625, 0.0
# this is loss for epoch 17 : 5351.662109375, 0.0
# this is loss for epoch 18 : 5137.42724609375, 0.0
# this is loss for epoch 19 : 4930.75048828125, 0.0
# this is loss for epoch 20 : 4731.6484375, 0.0
# this is loss for epoch 21 : 4540.17041015625, 0.0
# this is loss for epoch 22 : 4356.3291015625, 0.0
# this is loss for epoch 23 : 4180.07421875, 0.0
# this is loss for epoch 24 : 4011.300537109375, 0.0
# this is loss for epoch 25 : 3849.827880859375, 0.0
# this is loss for epoch 26 : 3695.380615234375, 0.0
# this is loss for epoch 27 : 3547.605224609375, 0.0
# this is loss for epoch 28 : 3406.123779296875, 0.0
# this is loss for epoch 29 : 3270.572021484375, 0.0
# this is loss for epoch 30 : 3140.595458984375, 0.0
# this is loss for epoch 31 : 3015.83544921875, 0.0
# this is loss for epoch 32 : 2895.91796875, 0.0
# this is loss for epoch 33 : 2780.463623046875, 0.0
# this is loss for epoch 34 : 2669.11083984375, 0.0
# this is loss for epoch 35 : 2561.577880859375, 0.0
# this is loss for epoch 36 : 2457.699951171875, 0.0
# this is loss for epoch 37 : 2357.438720703125, 0.0
# this is loss for epoch 38 : 2260.869873046875, 0.0
# this is loss for epoch 39 : 2168.137451171875, 0.0
# this is loss for epoch 40 : 2079.355712890625, 0.0
# this is loss for epoch 41 : 1994.5234375, 0.0
# this is loss for epoch 42 : 1913.5120849609375, 0.0
# this is loss for epoch 43 : 1836.103515625, 0.0
# this is loss for epoch 44 : 1762.013916015625, 0.0
# this is loss for epoch 45 : 1690.9041748046875, 0.0
# this is loss for epoch 46 : 1622.4586181640625, 0.0
# this is loss for epoch 47 : 1556.5062255859375, 0.0
# this is loss for epoch 48 : 1493.0306396484375, 0.0
# this is loss for epoch 49 : 1432.0911865234375, 0.0
# this is loss for epoch 50 : 1373.7174072265625, 0.0
# this is loss for epoch 51 : 1317.8441162109375, 0.0
# this is loss for epoch 52 : 1264.3521728515625, 0.0
# this is loss for epoch 53 : 1213.15283203125, 0.0
# this is loss for epoch 54 : 1164.2103271484375, 0.0
# this is loss for epoch 55 : 1117.5032958984375, 0.0
# this is loss for epoch 56 : 1072.98828125, 0.0
# this is loss for epoch 57 : 1030.5955810546875, 0.0
# this is loss for epoch 58 : 990.21484375, 0.0
# this is loss for epoch 59 : 951.6778564453125, 0.0
# this is loss for epoch 60 : 914.7701416015625, 0.0
# this is loss for epoch 61 : 879.31884765625, 0.0
# this is loss for epoch 62 : 845.2374267578125, 0.0
# this is loss for epoch 63 : 812.4521484375, 0.0
# this is loss for epoch 64 : 780.878173828125, 0.0
# this is loss for epoch 65 : 750.4547729492188, 0.0
# this is loss for epoch 66 : 721.1702880859375, 0.0
# this is loss for epoch 67 : 693.06640625, 0.0
# this is loss for epoch 68 : 666.2003173828125, 0.0
# this is loss for epoch 69 : 640.6173095703125, 0.0
# this is loss for epoch 70 : 616.3198852539062, 0.0
# this is loss for epoch 71 : 593.209228515625, 0.0
# this is loss for epoch 72 : 571.096435546875, 0.0
# this is loss for epoch 73 : 549.7677001953125, 0.0
# this is loss for epoch 74 : 529.0385131835938, 0.0
# this is loss for epoch 75 : 508.8009948730469, 0.0
# this is loss for epoch 76 : 489.033935546875, 0.0
# this is loss for epoch 77 : 469.78369140625, 0.0
# this is loss for epoch 78 : 451.1233825683594, 0.0
# this is loss for epoch 79 : 433.1220397949219, 0.0
# this is loss for epoch 80 : 415.82769775390625, 0.0
# this is loss for epoch 81 : 399.2499694824219, 0.0
# this is loss for epoch 82 : 383.3588562011719, 0.0
# this is loss for epoch 83 : 368.12274169921875, 0.0
# this is loss for epoch 84 : 353.5410461425781, 0.0
# this is loss for epoch 85 : 339.6291809082031, 0.0
# this is loss for epoch 86 : 326.36334228515625, 0.0
# this is loss for epoch 87 : 313.6513366699219, 0.0
# this is loss for epoch 88 : 301.40826416015625, 0.0
# this is loss for epoch 89 : 289.599609375, 0.0
# this is loss for epoch 90 : 278.1877746582031, 0.0
# this is loss for epoch 91 : 267.1209716796875, 0.0
# this is loss for epoch 92 : 256.3799133300781, 0.0
# this is loss for epoch 93 : 245.95449829101562, 0.0
# this is loss for epoch 94 : 235.8447723388672, 0.0
# this is loss for epoch 95 : 226.0751190185547, 0.0
# this is loss for epoch 96 : 216.6837921142578, 0.0
# this is loss for epoch 97 : 207.686279296875, 0.0
# this is loss for epoch 98 : 199.0350799560547, 0.0
# this is loss for epoch 99 : 190.66233825683594, 0.0
# this is loss for epoch 100 : 182.5514678955078, 0.0
# this is loss for epoch 101 : 174.75350952148438, 0.0
# this is loss for epoch 102 : 167.3502960205078, 0.0
# this is loss for epoch 103 : 160.3887939453125, 0.0
# this is loss for epoch 104 : 153.8793182373047, 0.0
# this is loss for epoch 105 : 147.80262756347656, 0.0
# this is loss for epoch 106 : 142.1177215576172, 0.0
# this is loss for epoch 107 : 136.77268981933594, 0.0
# this is loss for epoch 108 : 131.69593811035156, 0.0
# this is loss for epoch 109 : 126.84046936035156, 0.0
# this is loss for epoch 110 : 122.19972229003906, 0.0
# this is loss for epoch 111 : 117.76411437988281, 0.0
# this is loss for epoch 112 : 113.5099105834961, 0.0
# this is loss for epoch 113 : 109.41558074951172, 0.0
# this is loss for epoch 114 : 105.47442626953125, 0.0
# this is loss for epoch 115 : 101.69210052490234, 0.0
# this is loss for epoch 116 : 98.0906753540039, 0.0
# this is loss for epoch 117 : 94.67976379394531, 0.0
# this is loss for epoch 118 : 91.45374298095703, 0.0
# this is loss for epoch 119 : 88.3996353149414, 0.0
# this is loss for epoch 120 : 85.50343322753906, 0.0
# this is loss for epoch 121 : 82.74740600585938, 0.0
# this is loss for epoch 122 : 80.10953521728516, 0.0
# this is loss for epoch 123 : 77.57787322998047, 0.0
# this is loss for epoch 124 : 75.15821838378906, 0.0
# this is loss for epoch 125 : 72.84405517578125, 0.0
# this is loss for epoch 126 : 70.61280822753906, 0.0
# this is loss for epoch 127 : 68.44120025634766, 0.0
# this is loss for epoch 128 : 66.3252944946289, 0.0
# this is loss for epoch 129 : 64.29447174072266, 0.0
# this is loss for epoch 130 : 62.376678466796875, 0.0
# this is loss for epoch 131 : 60.57070541381836, 0.0
# this is loss for epoch 132 : 58.853057861328125, 0.0
# this is loss for epoch 133 : 57.217864990234375, 0.0
# this is loss for epoch 134 : 55.69788360595703, 0.0
# this is loss for epoch 135 : 54.32534408569336, 0.0
# this is loss for epoch 136 : 53.093238830566406, 0.0
# this is loss for epoch 137 : 51.96490478515625, 0.0
# this is loss for epoch 138 : 50.90581130981445, 0.0
# this is loss for epoch 139 : 49.889835357666016, 0.0
# this is loss for epoch 140 : 48.90495300292969, 0.0
# this is loss for epoch 141 : 47.94381332397461, 0.0
# this is loss for epoch 142 : 47.00657653808594, 0.0
# this is loss for epoch 143 : 46.100582122802734, 0.0
# this is loss for epoch 144 : 45.23699188232422, 0.0
# this is loss for epoch 145 : 44.42087936401367, 0.0
# this is loss for epoch 146 : 43.66360092163086, 0.0
# this is loss for epoch 147 : 42.959407806396484, 0.0
# this is loss for epoch 148 : 42.28565216064453, 0.0
# this is loss for epoch 149 : 41.62779235839844, 0.0
# this is loss for epoch 150 : 40.97750473022461, 0.0
# this is loss for epoch 151 : 40.33308410644531, 0.0
# this is loss for epoch 152 : 39.700645446777344, 0.0
# this is loss for epoch 153 : 39.08803939819336, 0.0
# this is loss for epoch 154 : 38.496849060058594, 0.0
# this is loss for epoch 155 : 37.9283447265625, 0.0
# this is loss for epoch 156 : 37.39102554321289, 0.0
# this is loss for epoch 157 : 36.885154724121094, 0.0
# this is loss for epoch 158 : 36.410213470458984, 0.0
# this is loss for epoch 159 : 35.95897674560547, 0.0
# this is loss for epoch 160 : 35.51527786254883, 0.0
# this is loss for epoch 161 : 35.07224655151367, 0.0
# this is loss for epoch 162 : 34.636226654052734, 0.0
# this is loss for epoch 163 : 34.21841049194336, 0.0
# this is loss for epoch 164 : 33.81858825683594, 0.0
# this is loss for epoch 165 : 33.42978286743164, 0.0
# this is loss for epoch 166 : 33.052490234375, 0.0
# this is loss for epoch 167 : 32.68193435668945, 0.0
# this is loss for epoch 168 : 32.31393051147461, 0.0
# this is loss for epoch 169 : 31.951309204101562, 0.0
# this is loss for epoch 170 : 31.60064697265625, 0.0
# this is loss for epoch 171 : 31.267438888549805, 0.0
# this is loss for epoch 172 : 30.961530685424805, 0.0
# this is loss for epoch 173 : 30.686193466186523, 0.0
# this is loss for epoch 174 : 30.429296493530273, 0.0
# this is loss for epoch 175 : 30.174530029296875, 0.0
# this is loss for epoch 176 : 29.91326904296875, 0.0
# this is loss for epoch 177 : 29.653074264526367, 0.0
# this is loss for epoch 178 : 29.401987075805664, 0.0
# this is loss for epoch 179 : 29.15732765197754, 0.0
# this is loss for epoch 180 : 28.91617774963379, 0.0
# this is loss for epoch 181 : 28.680688858032227, 0.0
# this is loss for epoch 182 : 28.448957443237305, 0.0
# this is loss for epoch 183 : 28.21803855895996, 0.0
# this is loss for epoch 184 : 27.989973068237305, 0.0
# this is loss for epoch 185 : 27.76239585876465, 0.0
# this is loss for epoch 186 : 27.5351619720459, 0.0
# this is loss for epoch 187 : 27.309202194213867, 0.0
# this is loss for epoch 188 : 27.08424186706543, 0.0
# this is loss for epoch 189 : 26.863723754882812, 0.0
# this is loss for epoch 190 : 26.6534423828125, 0.0
# this is loss for epoch 191 : 26.4608211517334, 0.0
# this is loss for epoch 192 : 26.291723251342773, 0.0
# this is loss for epoch 193 : 26.136865615844727, 0.0
# this is loss for epoch 194 : 25.977914810180664, 0.0
# this is loss for epoch 195 : 25.808719635009766, 0.0
# this is loss for epoch 196 : 25.632314682006836, 0.0
# this is loss for epoch 197 : 25.454591751098633, 0.0
# this is loss for epoch 198 : 25.281064987182617, 0.0
# this is loss for epoch 199 : 25.116701126098633, 0.0
# this is loss for epoch 200 : 24.962709426879883, 0.0
# this is loss for epoch 201 : 24.817821502685547, 0.0
# this is loss for epoch 202 : 24.676513671875, 0.0
# this is loss for epoch 203 : 24.529956817626953, 0.0
# this is loss for epoch 204 : 24.376951217651367, 0.0
# this is loss for epoch 205 : 24.219789505004883, 0.0
# this is loss for epoch 206 : 24.06093978881836, 0.0
# this is loss for epoch 207 : 23.901050567626953, 0.0
# this is loss for epoch 208 : 23.738845825195312, 0.0
# this is loss for epoch 209 : 23.573680877685547, 0.0
# this is loss for epoch 210 : 23.406362533569336, 0.0
# this is loss for epoch 211 : 23.241127014160156, 0.0
# this is loss for epoch 212 : 23.084030151367188, 0.0
# this is loss for epoch 213 : 22.934919357299805, 0.0
# this is loss for epoch 214 : 22.780330657958984, 0.0
# this is loss for epoch 215 : 22.61544418334961, 0.0
# this is loss for epoch 216 : 22.45332908630371, 0.0
# this is loss for epoch 217 : 22.3101806640625, 0.0
# this is loss for epoch 218 : 22.193212509155273, 0.0
# this is loss for epoch 219 : 22.094284057617188, 0.0
# this is loss for epoch 220 : 21.996267318725586, 0.0
# this is loss for epoch 221 : 21.889867782592773, 0.0
# this is loss for epoch 222 : 21.773893356323242, 0.0
# this is loss for epoch 223 : 21.651405334472656, 0.0
# this is loss for epoch 224 : 21.528411865234375, 0.0
# this is loss for epoch 225 : 21.407299041748047, 0.0
# this is loss for epoch 226 : 21.289722442626953, 0.0
# this is loss for epoch 227 : 21.17630958557129, 0.0
# this is loss for epoch 228 : 21.06618309020996, 0.0
# this is loss for epoch 229 : 20.95808219909668, 0.0
# this is loss for epoch 230 : 20.850278854370117, 0.0
# this is loss for epoch 231 : 20.74100112915039, 0.0
# this is loss for epoch 232 : 20.62895965576172, 0.0
# this is loss for epoch 233 : 20.512983322143555, 0.0
# this is loss for epoch 234 : 20.395553588867188, 0.0
# this is loss for epoch 235 : 20.28095817565918, 0.0
# this is loss for epoch 236 : 20.171588897705078, 0.0
# this is loss for epoch 237 : 20.063186645507812, 0.0
# this is loss for epoch 238 : 19.95041847229004, 0.0
# this is loss for epoch 239 : 19.833948135375977, 0.0
# this is loss for epoch 240 : 19.71420669555664, 0.0
# this is loss for epoch 241 : 19.595752716064453, 0.0
# this is loss for epoch 242 : 19.481998443603516, 0.0
# this is loss for epoch 243 : 19.3743839263916, 0.0
# this is loss for epoch 244 : 19.275278091430664, 0.0
# this is loss for epoch 245 : 19.18645477294922, 0.0
# this is loss for epoch 246 : 19.099098205566406, 0.0
# this is loss for epoch 247 : 19.004911422729492, 0.0
# this is loss for epoch 248 : 18.907440185546875, 0.0
# this is loss for epoch 249 : 18.81192398071289, 0.0
# this is loss for epoch 250 : 18.72030258178711, 0.0
# this is loss for epoch 251 : 18.63298797607422, 0.0
# this is loss for epoch 252 : 18.548097610473633, 0.0
# this is loss for epoch 253 : 18.462705612182617, 0.0
# this is loss for epoch 254 : 18.376949310302734, 0.0
# this is loss for epoch 255 : 18.29279327392578, 0.0
# this is loss for epoch 256 : 18.209245681762695, 0.0
# this is loss for epoch 257 : 18.12586212158203, 0.0
# this is loss for epoch 258 : 18.042512893676758, 0.0
# this is loss for epoch 259 : 17.961963653564453, 0.0
# this is loss for epoch 260 : 17.88515281677246, 0.0
# this is loss for epoch 261 : 17.809995651245117, 0.0
# this is loss for epoch 262 : 17.732572555541992, 0.0
# this is loss for epoch 263 : 17.652835845947266, 0.0
# this is loss for epoch 264 : 17.573720932006836, 0.0
# this is loss for epoch 265 : 17.499187469482422, 0.0
# this is loss for epoch 266 : 17.42974090576172, 0.0
# this is loss for epoch 267 : 17.358089447021484, 0.0
# this is loss for epoch 268 : 17.285261154174805, 0.0
# this is loss for epoch 269 : 17.214092254638672, 0.0
# this is loss for epoch 270 : 17.143230438232422, 0.0
# this is loss for epoch 271 : 17.072546005249023, 0.0
# this is loss for epoch 272 : 17.002758026123047, 0.0
# this is loss for epoch 273 : 16.93372917175293, 0.0
# this is loss for epoch 274 : 16.865562438964844, 0.0
# this is loss for epoch 275 : 16.79758644104004, 0.0
# this is loss for epoch 276 : 16.7304630279541, 0.0
# this is loss for epoch 277 : 16.663480758666992, 0.0
# this is loss for epoch 278 : 16.596710205078125, 0.0
# this is loss for epoch 279 : 16.529125213623047, 0.0
# this is loss for epoch 280 : 16.461322784423828, 0.0
# this is loss for epoch 281 : 16.394346237182617, 0.0
# this is loss for epoch 282 : 16.328062057495117, 0.0
# this is loss for epoch 283 : 16.262168884277344, 0.0
# this is loss for epoch 284 : 16.196067810058594, 0.0
# this is loss for epoch 285 : 16.129758834838867, 0.0
# this is loss for epoch 286 : 16.06260871887207, 0.0
# this is loss for epoch 287 : 15.996843338012695, 0.0
# this is loss for epoch 288 : 15.933642387390137, 0.0
# this is loss for epoch 289 : 15.871943473815918, 0.0
# this is loss for epoch 290 : 15.810391426086426, 0.0
# this is loss for epoch 291 : 15.74932861328125, 0.0
# this is loss for epoch 292 : 15.689749717712402, 0.0
# this is loss for epoch 293 : 15.630006790161133, 0.0
# this is loss for epoch 294 : 15.569772720336914, 0.0
# this is loss for epoch 295 : 15.510612487792969, 0.0
# this is loss for epoch 296 : 15.452478408813477, 0.0
# this is loss for epoch 297 : 15.394673347473145, 0.0
# this is loss for epoch 298 : 15.337325096130371, 0.0
# this is loss for epoch 299 : 15.280174255371094, 0.0
# this is loss for epoch 300 : 15.22312068939209, 0.0
# this is loss for epoch 301 : 15.166078567504883, 0.0
# this is loss for epoch 302 : 15.108830451965332, 0.0
# this is loss for epoch 303 : 15.05179500579834, 0.0
# this is loss for epoch 304 : 14.995144844055176, 0.0
# this is loss for epoch 305 : 14.93885326385498, 0.0
# this is loss for epoch 306 : 14.883356094360352, 0.0
# this is loss for epoch 307 : 14.829523086547852, 0.0
# this is loss for epoch 308 : 14.776257514953613, 0.0
# this is loss for epoch 309 : 14.721638679504395, 0.0
# this is loss for epoch 310 : 14.667065620422363, 0.0
# this is loss for epoch 311 : 14.613351821899414, 0.0
# this is loss for epoch 312 : 14.560078620910645, 0.0
# this is loss for epoch 313 : 14.506464004516602, 0.0
# this is loss for epoch 314 : 14.45256519317627, 0.0
# this is loss for epoch 315 : 14.398126602172852, 0.0
# this is loss for epoch 316 : 14.343317031860352, 0.0
# this is loss for epoch 317 : 14.288042068481445, 0.0
# this is loss for epoch 318 : 14.23188304901123, 0.0
# this is loss for epoch 319 : 14.175396919250488, 0.0
# this is loss for epoch 320 : 14.11927318572998, 0.0
# this is loss for epoch 321 : 14.063422203063965, 0.0
# this is loss for epoch 322 : 14.008699417114258, 0.0
# this is loss for epoch 323 : 13.954690933227539, 0.0
# this is loss for epoch 324 : 13.902055740356445, 0.0
# this is loss for epoch 325 : 13.853045463562012, 0.0
# this is loss for epoch 326 : 13.801360130310059, 0.0
# this is loss for epoch 327 : 13.747629165649414, 0.0
# this is loss for epoch 328 : 13.69444751739502, 0.0
# this is loss for epoch 329 : 13.643625259399414, 0.0
# this is loss for epoch 330 : 13.593507766723633, 0.0
# this is loss for epoch 331 : 13.543214797973633, 0.0
# this is loss for epoch 332 : 13.492863655090332, 0.0
# this is loss for epoch 333 : 13.442038536071777, 0.0
# this is loss for epoch 334 : 13.391827583312988, 0.0
# this is loss for epoch 335 : 13.343124389648438, 0.0
# this is loss for epoch 336 : 13.294478416442871, 0.0
# this is loss for epoch 337 : 13.245892524719238, 0.0
# this is loss for epoch 338 : 13.197644233703613, 0.0
# this is loss for epoch 339 : 13.149336814880371, 0.0
# this is loss for epoch 340 : 13.101333618164062, 0.0
# this is loss for epoch 341 : 13.054056167602539, 0.0
# this is loss for epoch 342 : 13.008002281188965, 0.0
# this is loss for epoch 343 : 12.962607383728027, 0.0
# this is loss for epoch 344 : 12.917479515075684, 0.0
# this is loss for epoch 345 : 12.872713088989258, 0.0
# this is loss for epoch 346 : 12.828085899353027, 0.0
# this is loss for epoch 347 : 12.783949851989746, 0.0
# this is loss for epoch 348 : 12.739821434020996, 0.0
# this is loss for epoch 349 : 12.695704460144043, 0.0
# this is loss for epoch 350 : 12.651459693908691, 0.0
# this is loss for epoch 351 : 12.60742473602295, 0.0
# this is loss for epoch 352 : 12.563441276550293, 0.0
# this is loss for epoch 353 : 12.520167350769043, 0.0
# this is loss for epoch 354 : 12.477458000183105, 0.0
# this is loss for epoch 355 : 12.434516906738281, 0.0
# this is loss for epoch 356 : 12.391642570495605, 0.0
# this is loss for epoch 357 : 12.349395751953125, 0.0
# this is loss for epoch 358 : 12.307598114013672, 0.0
# this is loss for epoch 359 : 12.266509056091309, 0.0
# this is loss for epoch 360 : 12.225902557373047, 0.0
# this is loss for epoch 361 : 12.184709548950195, 0.0
# this is loss for epoch 362 : 12.143218040466309, 0.0
# this is loss for epoch 363 : 12.102200508117676, 0.0
# this is loss for epoch 364 : 12.061884880065918, 0.0
# this is loss for epoch 365 : 12.022171974182129, 0.0
# this is loss for epoch 366 : 11.982548713684082, 0.0
# this is loss for epoch 367 : 11.942896842956543, 0.0
# this is loss for epoch 368 : 11.903429985046387, 0.0
# this is loss for epoch 369 : 11.864297866821289, 0.0
# this is loss for epoch 370 : 11.825251579284668, 0.0
# this is loss for epoch 371 : 11.786032676696777, 0.0
# this is loss for epoch 372 : 11.746939659118652, 0.0
# this is loss for epoch 373 : 11.708098411560059, 0.0
# this is loss for epoch 374 : 11.669575691223145, 0.0
# this is loss for epoch 375 : 11.631390571594238, 0.0
# this is loss for epoch 376 : 11.59326457977295, 0.0
# this is loss for epoch 377 : 11.55522346496582, 0.0
# this is loss for epoch 378 : 11.517036437988281, 0.0
# this is loss for epoch 379 : 11.478930473327637, 0.0
# this is loss for epoch 380 : 11.44127368927002, 0.0
# this is loss for epoch 381 : 11.40424633026123, 0.0
# this is loss for epoch 382 : 11.367627143859863, 0.0
# this is loss for epoch 383 : 11.331084251403809, 0.0
# this is loss for epoch 384 : 11.294085502624512, 0.0
# this is loss for epoch 385 : 11.257421493530273, 0.0
# this is loss for epoch 386 : 11.221673965454102, 0.0
# this is loss for epoch 387 : 11.186287879943848, 0.0
# this is loss for epoch 388 : 11.150689125061035, 0.0
# this is loss for epoch 389 : 11.115473747253418, 0.0
# this is loss for epoch 390 : 11.080687522888184, 0.0
# this is loss for epoch 391 : 11.045930862426758, 0.0
# this is loss for epoch 392 : 11.010953903198242, 0.0
# this is loss for epoch 393 : 10.976076126098633, 0.0
# this is loss for epoch 394 : 10.941600799560547, 0.0
# this is loss for epoch 395 : 10.907389640808105, 0.0
# this is loss for epoch 396 : 10.873431205749512, 0.0
# this is loss for epoch 397 : 10.839350700378418, 0.0
# this is loss for epoch 398 : 10.805810928344727, 0.0
# this is loss for epoch 399 : 10.773554801940918, 0.0
# this is loss for epoch 400 : 10.741896629333496, 0.0
# this is loss for epoch 401 : 10.709280967712402, 0.0
# this is loss for epoch 402 : 10.676793098449707, 0.0
# this is loss for epoch 403 : 10.645030975341797, 0.0
# this is loss for epoch 404 : 10.613543510437012, 0.0
# this is loss for epoch 405 : 10.5823974609375, 0.0
# this is loss for epoch 406 : 10.551358222961426, 0.0
# this is loss for epoch 407 : 10.520434379577637, 0.0
# this is loss for epoch 408 : 10.490069389343262, 0.0
# this is loss for epoch 409 : 10.460111618041992, 0.0
# this is loss for epoch 410 : 10.4303617477417, 0.0
# this is loss for epoch 411 : 10.400850296020508, 0.0
# this is loss for epoch 412 : 10.371307373046875, 0.0
# this is loss for epoch 413 : 10.342026710510254, 0.0
# this is loss for epoch 414 : 10.313322067260742, 0.0
# this is loss for epoch 415 : 10.284950256347656, 0.0
# this is loss for epoch 416 : 10.256799697875977, 0.0
# this is loss for epoch 417 : 10.228540420532227, 0.0
# this is loss for epoch 418 : 10.200775146484375, 0.0
# this is loss for epoch 419 : 10.173568725585938, 0.0
# this is loss for epoch 420 : 10.146418571472168, 0.0
# this is loss for epoch 421 : 10.11957836151123, 0.0
# this is loss for epoch 422 : 10.09289836883545, 0.0
# this is loss for epoch 423 : 10.066195487976074, 0.0
# this is loss for epoch 424 : 10.039732933044434, 0.0
# this is loss for epoch 425 : 10.013535499572754, 0.0
# this is loss for epoch 426 : 9.987406730651855, 0.0
# this is loss for epoch 427 : 9.961430549621582, 0.0
# this is loss for epoch 428 : 9.935768127441406, 0.0
# this is loss for epoch 429 : 9.910359382629395, 0.0
# this is loss for epoch 430 : 9.885087966918945, 0.0
# this is loss for epoch 431 : 9.860381126403809, 0.0
# this is loss for epoch 432 : 9.835675239562988, 0.0
# this is loss for epoch 433 : 9.81082820892334, 0.0
# this is loss for epoch 434 : 9.786011695861816, 0.0
# this is loss for epoch 435 : 9.76128101348877, 0.0
# this is loss for epoch 436 : 9.736444473266602, 0.0
# this is loss for epoch 437 : 9.710944175720215, 0.0
# this is loss for epoch 438 : 9.684788703918457, 0.0
# this is loss for epoch 439 : 9.657862663269043, 0.0
# this is loss for epoch 440 : 9.629823684692383, 0.0
# this is loss for epoch 441 : 9.600604057312012, 0.0
# this is loss for epoch 442 : 9.570651054382324, 0.0
# this is loss for epoch 443 : 9.541777610778809, 0.0
# this is loss for epoch 444 : 9.517566680908203, 0.0
# this is loss for epoch 445 : 9.499640464782715, 0.0
# this is loss for epoch 446 : 9.4780912399292, 0.0
# this is loss for epoch 447 : 9.452845573425293, 0.0
# this is loss for epoch 448 : 9.429922103881836, 0.0
# this is loss for epoch 449 : 9.410436630249023, 0.0
# this is loss for epoch 450 : 9.390567779541016, 0.0
# this is loss for epoch 451 : 9.368513107299805, 0.0
# this is loss for epoch 452 : 9.345245361328125, 0.0
# this is loss for epoch 453 : 9.322531700134277, 0.0
# this is loss for epoch 454 : 9.30126953125, 0.0
# this is loss for epoch 455 : 9.28116512298584, 0.0
# this is loss for epoch 456 : 9.26130199432373, 0.0
# this is loss for epoch 457 : 9.241128921508789, 0.0
# this is loss for epoch 458 : 9.220344543457031, 0.0
# this is loss for epoch 459 : 9.199262619018555, 0.0
# this is loss for epoch 460 : 9.178304672241211, 0.0
# this is loss for epoch 461 : 9.157691955566406, 0.0
# this is loss for epoch 462 : 9.137566566467285, 0.0
# this is loss for epoch 463 : 9.11781120300293, 0.0
# this is loss for epoch 464 : 9.098176956176758, 0.0
# this is loss for epoch 465 : 9.078062057495117, 0.0
# this is loss for epoch 466 : 9.057596206665039, 0.0
# this is loss for epoch 467 : 9.037481307983398, 0.0
# this is loss for epoch 468 : 9.017661094665527, 0.0
# this is loss for epoch 469 : 8.998431205749512, 0.0
# this is loss for epoch 470 : 8.979658126831055, 0.0
# this is loss for epoch 471 : 8.961170196533203, 0.0
# this is loss for epoch 472 : 8.942598342895508, 0.0
# this is loss for epoch 473 : 8.92423152923584, 0.0
# this is loss for epoch 474 : 8.906206130981445, 0.0
# this is loss for epoch 475 : 8.88769245147705, 0.0
# this is loss for epoch 476 : 8.869561195373535, 0.0
# this is loss for epoch 477 : 8.85083293914795, 0.0
# this is loss for epoch 478 : 8.831855773925781, 0.0
# this is loss for epoch 479 : 8.812976837158203, 0.0
# this is loss for epoch 480 : 8.79391098022461, 0.0
# this is loss for epoch 481 : 8.775126457214355, 0.0
# this is loss for epoch 482 : 8.756684303283691, 0.0
# this is loss for epoch 483 : 8.740653038024902, 0.0
# this is loss for epoch 484 : 8.723957061767578, 0.0
# this is loss for epoch 485 : 8.705772399902344, 0.0
# this is loss for epoch 486 : 8.688114166259766, 0.0
# this is loss for epoch 487 : 8.671711921691895, 0.0
# this is loss for epoch 488 : 8.655531883239746, 0.0
# this is loss for epoch 489 : 8.6391019821167, 0.0
# this is loss for epoch 490 : 8.622210502624512, 0.0
# this is loss for epoch 491 : 8.605066299438477, 0.0
# this is loss for epoch 492 : 8.587956428527832, 0.0
# this is loss for epoch 493 : 8.571248054504395, 0.0
# this is loss for epoch 494 : 8.554770469665527, 0.0
# this is loss for epoch 495 : 8.537697792053223, 0.0
# this is loss for epoch 496 : 8.519850730895996, 0.0
# this is loss for epoch 497 : 8.50127124786377, 0.0
# this is loss for epoch 498 : 8.48234748840332, 0.0
# this is loss for epoch 499 : 8.463613510131836, 0.0
# this is loss for epoch 500 : 8.446457862854004, 0.0
# this is loss for epoch 501 : 8.431011199951172, 0.0
# this is loss for epoch 502 : 8.414839744567871, 0.0
# this is loss for epoch 503 : 8.398673057556152, 0.0
# this is loss for epoch 504 : 8.381657600402832, 0.0
# this is loss for epoch 505 : 8.36535930633545, 0.0
# this is loss for epoch 506 : 8.350214004516602, 0.0
# this is loss for epoch 507 : 8.33552074432373, 0.0
# this is loss for epoch 508 : 8.31986141204834, 0.0
# this is loss for epoch 509 : 8.304618835449219, 0.0
# this is loss for epoch 510 : 8.289481163024902, 0.0
# this is loss for epoch 511 : 8.274821281433105, 0.0
# this is loss for epoch 512 : 8.259820938110352, 0.0
# this is loss for epoch 513 : 8.244670867919922, 0.0
# this is loss for epoch 514 : 8.22988510131836, 0.0
# this is loss for epoch 515 : 8.215356826782227, 0.0
# this is loss for epoch 516 : 8.200995445251465, 0.0
# this is loss for epoch 517 : 8.186823844909668, 0.0
# this is loss for epoch 518 : 8.172383308410645, 0.0
# this is loss for epoch 519 : 8.157637596130371, 0.0
# this is loss for epoch 520 : 8.143043518066406, 0.0
# this is loss for epoch 521 : 8.128442764282227, 0.0
# this is loss for epoch 522 : 8.11384105682373, 0.0
# this is loss for epoch 523 : 8.099029541015625, 0.0
# this is loss for epoch 524 : 8.083800315856934, 0.0
# this is loss for epoch 525 : 8.068341255187988, 0.0
# this is loss for epoch 526 : 8.052287101745605, 0.0
# this is loss for epoch 527 : 8.035816192626953, 0.0
# this is loss for epoch 528 : 8.018570899963379, 0.0
# this is loss for epoch 529 : 8.000247955322266, 0.0
# this is loss for epoch 530 : 7.981209754943848, 0.0
# this is loss for epoch 531 : 7.961485385894775, 0.0
# this is loss for epoch 532 : 7.941981792449951, 0.0
# this is loss for epoch 533 : 7.923465728759766, 0.0
# this is loss for epoch 534 : 7.906309604644775, 0.0
# this is loss for epoch 535 : 7.890608310699463, 0.0
# this is loss for epoch 536 : 7.875833034515381, 0.0
# this is loss for epoch 537 : 7.861374855041504, 0.0
# this is loss for epoch 538 : 7.847283363342285, 0.0
# this is loss for epoch 539 : 7.833632946014404, 0.0
# this is loss for epoch 540 : 7.820828437805176, 0.0
# this is loss for epoch 541 : 7.807887554168701, 0.0
# this is loss for epoch 542 : 7.794378757476807, 0.0
# this is loss for epoch 543 : 7.780947208404541, 0.0
# this is loss for epoch 544 : 7.767599582672119, 0.0
# this is loss for epoch 545 : 7.754204750061035, 0.0
# this is loss for epoch 546 : 7.740920543670654, 0.0
# this is loss for epoch 547 : 7.727916717529297, 0.0
# this is loss for epoch 548 : 7.714927673339844, 0.0
# this is loss for epoch 549 : 7.7018914222717285, 0.0
# this is loss for epoch 550 : 7.688763618469238, 0.0
# this is loss for epoch 551 : 7.675570011138916, 0.0
# this is loss for epoch 552 : 7.662291049957275, 0.0
# this is loss for epoch 553 : 7.649163722991943, 0.0
# this is loss for epoch 554 : 7.635982513427734, 0.0
# this is loss for epoch 555 : 7.622904300689697, 0.0
# this is loss for epoch 556 : 7.609853267669678, 0.0
# this is loss for epoch 557 : 7.596730709075928, 0.0
# this is loss for epoch 558 : 7.583690166473389, 0.0
# this is loss for epoch 559 : 7.570797920227051, 0.0
# this is loss for epoch 560 : 7.558387279510498, 0.0
# this is loss for epoch 561 : 7.5457611083984375, 0.0
# this is loss for epoch 562 : 7.532987117767334, 0.0
# this is loss for epoch 563 : 7.5202460289001465, 0.0
# this is loss for epoch 564 : 7.507200717926025, 0.0
# this is loss for epoch 565 : 7.4936723709106445, 0.0
# this is loss for epoch 566 : 7.480005741119385, 0.0
# this is loss for epoch 567 : 7.466566562652588, 0.0
# this is loss for epoch 568 : 7.453557014465332, 0.0
# this is loss for epoch 569 : 7.439476013183594, 0.0
# this is loss for epoch 570 : 7.425933837890625, 0.0
# this is loss for epoch 571 : 7.413907527923584, 0.0
# this is loss for epoch 572 : 7.401650905609131, 0.0
# this is loss for epoch 573 : 7.390369415283203, 0.0
# this is loss for epoch 574 : 7.377830505371094, 0.0
# this is loss for epoch 575 : 7.3650970458984375, 0.0
# this is loss for epoch 576 : 7.352869510650635, 0.0
# this is loss for epoch 577 : 7.341042518615723, 0.0
# this is loss for epoch 578 : 7.3290019035339355, 0.0
# this is loss for epoch 579 : 7.316987037658691, 0.0
# this is loss for epoch 580 : 7.305139064788818, 0.0
# this is loss for epoch 581 : 7.293466091156006, 0.0
# this is loss for epoch 582 : 7.281426906585693, 0.0
# this is loss for epoch 583 : 7.269238471984863, 0.0
# this is loss for epoch 584 : 7.257393836975098, 0.0
# this is loss for epoch 585 : 7.245942115783691, 0.0
# this is loss for epoch 586 : 7.234670162200928, 0.0
# this is loss for epoch 587 : 7.223400115966797, 0.0
# this is loss for epoch 588 : 7.212123394012451, 0.0
# this is loss for epoch 589 : 7.200920104980469, 0.0
# this is loss for epoch 590 : 7.189736366271973, 0.0
# this is loss for epoch 591 : 7.178514003753662, 0.0
# this is loss for epoch 592 : 7.167336940765381, 0.0
# this is loss for epoch 593 : 7.156296730041504, 0.0
# this is loss for epoch 594 : 7.1453471183776855, 0.0
# this is loss for epoch 595 : 7.134415626525879, 0.0
# this is loss for epoch 596 : 7.123333930969238, 0.0
# this is loss for epoch 597 : 7.112245082855225, 0.0
# this is loss for epoch 598 : 7.10134744644165, 0.0
# this is loss for epoch 599 : 7.090508460998535, 0.0
# this is loss for epoch 600 : 7.0794901847839355, 0.0
# this is loss for epoch 601 : 7.068426609039307, 0.0
# this is loss for epoch 602 : 7.057430267333984, 0.0
# this is loss for epoch 603 : 7.0461602210998535, 0.0
# this is loss for epoch 604 : 7.034896373748779, 0.0
# this is loss for epoch 605 : 7.023653507232666, 0.0
# this is loss for epoch 606 : 7.012213230133057, 0.0
# this is loss for epoch 607 : 7.000709056854248, 0.0
# this is loss for epoch 608 : 6.989192962646484, 0.0
# this is loss for epoch 609 : 6.977241039276123, 0.0
# this is loss for epoch 610 : 6.965636730194092, 0.0
# this is loss for epoch 611 : 6.9534173011779785, 0.0
# this is loss for epoch 612 : 6.940148830413818, 0.0
# this is loss for epoch 613 : 6.925955295562744, 0.0
# this is loss for epoch 614 : 6.910585880279541, 0.0
# this is loss for epoch 615 : 6.893933296203613, 0.0
# this is loss for epoch 616 : 6.875563144683838, 0.0
# this is loss for epoch 617 : 6.855716228485107, 0.0
# this is loss for epoch 618 : 6.835658550262451, 0.0
# this is loss for epoch 619 : 6.817063808441162, 0.0
# this is loss for epoch 620 : 6.800783634185791, 0.0
# this is loss for epoch 621 : 6.786895275115967, 0.0
# this is loss for epoch 622 : 6.774596691131592, 0.0
# this is loss for epoch 623 : 6.7633256912231445, 0.0
# this is loss for epoch 624 : 6.752620220184326, 0.0
# this is loss for epoch 625 : 6.74228048324585, 0.0
# this is loss for epoch 626 : 6.732032299041748, 0.0
# this is loss for epoch 627 : 6.721748352050781, 0.0
# this is loss for epoch 628 : 6.7114129066467285, 0.0
# this is loss for epoch 629 : 6.701120853424072, 0.0
# this is loss for epoch 630 : 6.690834045410156, 0.0
# this is loss for epoch 631 : 6.680589199066162, 0.0
# this is loss for epoch 632 : 6.670231819152832, 0.0
# this is loss for epoch 633 : 6.659879207611084, 0.0
# this is loss for epoch 634 : 6.649445533752441, 0.0
# this is loss for epoch 635 : 6.638950347900391, 0.0
# this is loss for epoch 636 : 6.628363132476807, 0.0
# this is loss for epoch 637 : 6.617750644683838, 0.0
# this is loss for epoch 638 : 6.607276439666748, 0.0
# this is loss for epoch 639 : 6.596901893615723, 0.0
# this is loss for epoch 640 : 6.586386203765869, 0.0
# this is loss for epoch 641 : 6.575852394104004, 0.0
# this is loss for epoch 642 : 6.56549072265625, 0.0
# this is loss for epoch 643 : 6.555127143859863, 0.0
# this is loss for epoch 644 : 6.544753551483154, 0.0
# this is loss for epoch 645 : 6.534613132476807, 0.0
# this is loss for epoch 646 : 6.524766445159912, 0.0
# this is loss for epoch 647 : 6.514889717102051, 0.0
# this is loss for epoch 648 : 6.5048508644104, 0.0
# this is loss for epoch 649 : 6.494991302490234, 0.0
# this is loss for epoch 650 : 6.485215663909912, 0.0
# this is loss for epoch 651 : 6.475368499755859, 0.0
# this is loss for epoch 652 : 6.465479373931885, 0.0
# this is loss for epoch 653 : 6.455679416656494, 0.0
# this is loss for epoch 654 : 6.445949077606201, 0.0
# this is loss for epoch 655 : 6.4363837242126465, 0.0
# this is loss for epoch 656 : 6.4265289306640625, 0.0
# this is loss for epoch 657 : 6.416775703430176, 0.0
# this is loss for epoch 658 : 6.406984806060791, 0.0
# this is loss for epoch 659 : 6.396914005279541, 0.0
# this is loss for epoch 660 : 6.386600017547607, 0.0
# this is loss for epoch 661 : 6.3762736320495605, 0.0
# this is loss for epoch 662 : 6.366291046142578, 0.0
# this is loss for epoch 663 : 6.357598304748535, 0.0
# this is loss for epoch 664 : 6.348330974578857, 0.0
# this is loss for epoch 665 : 6.339075088500977, 0.0
# this is loss for epoch 666 : 6.329576015472412, 0.0
# this is loss for epoch 667 : 6.319956302642822, 0.0
# this is loss for epoch 668 : 6.3103508949279785, 0.0
# this is loss for epoch 669 : 6.300895690917969, 0.0
# this is loss for epoch 670 : 6.291696071624756, 0.0
# this is loss for epoch 671 : 6.2826385498046875, 0.0
# this is loss for epoch 672 : 6.2732930183410645, 0.0
# this is loss for epoch 673 : 6.263880252838135, 0.0
# this is loss for epoch 674 : 6.254554271697998, 0.0
# this is loss for epoch 675 : 6.24547815322876, 0.0
# this is loss for epoch 676 : 6.236217498779297, 0.0
# this is loss for epoch 677 : 6.227099895477295, 0.0
# this is loss for epoch 678 : 6.218031883239746, 0.0
# this is loss for epoch 679 : 6.208702564239502, 0.0
# this is loss for epoch 680 : 6.199746608734131, 0.0
# this is loss for epoch 681 : 6.190513610839844, 0.0
# this is loss for epoch 682 : 6.181693077087402, 0.0
# this is loss for epoch 683 : 6.172703266143799, 0.0
# this is loss for epoch 684 : 6.163671016693115, 0.0
# this is loss for epoch 685 : 6.154747486114502, 0.0
# this is loss for epoch 686 : 6.145726203918457, 0.0
# this is loss for epoch 687 : 6.136837959289551, 0.0
# this is loss for epoch 688 : 6.12766170501709, 0.0
# this is loss for epoch 689 : 6.118537425994873, 0.0
# this is loss for epoch 690 : 6.109466075897217, 0.0
# this is loss for epoch 691 : 6.10045051574707, 0.0
# this is loss for epoch 692 : 6.091262340545654, 0.0
# this is loss for epoch 693 : 6.081817150115967, 0.0
# this is loss for epoch 694 : 6.072338581085205, 0.0
# this is loss for epoch 695 : 6.063024044036865, 0.0
# this is loss for epoch 696 : 6.054111957550049, 0.0
# this is loss for epoch 697 : 6.045019626617432, 0.0
# this is loss for epoch 698 : 6.036313056945801, 0.0
# this is loss for epoch 699 : 6.027609348297119, 0.0
# this is loss for epoch 700 : 6.019265651702881, 0.0
# this is loss for epoch 701 : 6.010924339294434, 0.0
# this is loss for epoch 702 : 6.002424716949463, 0.0
# this is loss for epoch 703 : 5.993999481201172, 0.0
# this is loss for epoch 704 : 5.985767841339111, 0.0
# this is loss for epoch 705 : 5.97759485244751, 0.0
# this is loss for epoch 706 : 5.969262599945068, 0.0
# this is loss for epoch 707 : 5.960867881774902, 0.0
# this is loss for epoch 708 : 5.952599048614502, 0.0
# this is loss for epoch 709 : 5.9444580078125, 0.0
# this is loss for epoch 710 : 5.936213970184326, 0.0
# this is loss for epoch 711 : 5.927855968475342, 0.0
# this is loss for epoch 712 : 5.919625759124756, 0.0
# this is loss for epoch 713 : 5.911431312561035, 0.0
# this is loss for epoch 714 : 5.9031548500061035, 0.0
# this is loss for epoch 715 : 5.894742488861084, 0.0
# this is loss for epoch 716 : 5.886268138885498, 0.0
# this is loss for epoch 717 : 5.877745151519775, 0.0
# this is loss for epoch 718 : 5.86909818649292, 0.0
# this is loss for epoch 719 : 5.860466003417969, 0.0
# this is loss for epoch 720 : 5.852132320404053, 0.0
# this is loss for epoch 721 : 5.844460964202881, 0.0
# this is loss for epoch 722 : 5.836434364318848, 0.0
# this is loss for epoch 723 : 5.827959060668945, 0.0
# this is loss for epoch 724 : 5.819544315338135, 0.0
# this is loss for epoch 725 : 5.811411380767822, 0.0
# this is loss for epoch 726 : 5.803475379943848, 0.0
# this is loss for epoch 727 : 5.795333385467529, 0.0
# this is loss for epoch 728 : 5.787331581115723, 0.0
# this is loss for epoch 729 : 5.779277801513672, 0.0
# this is loss for epoch 730 : 5.771121501922607, 0.0
# this is loss for epoch 731 : 5.763010025024414, 0.0
# this is loss for epoch 732 : 5.755016803741455, 0.0
# this is loss for epoch 733 : 5.747004985809326, 0.0
# this is loss for epoch 734 : 5.739064693450928, 0.0
# this is loss for epoch 735 : 5.731117248535156, 0.0
# this is loss for epoch 736 : 5.723286151885986, 0.0
# this is loss for epoch 737 : 5.715404033660889, 0.0
# this is loss for epoch 738 : 5.707468509674072, 0.0
# this is loss for epoch 739 : 5.699508190155029, 0.0
# this is loss for epoch 740 : 5.691535949707031, 0.0
# this is loss for epoch 741 : 5.6835856437683105, 0.0
# this is loss for epoch 742 : 5.675654411315918, 0.0
# this is loss for epoch 743 : 5.667684078216553, 0.0
# this is loss for epoch 744 : 5.659846305847168, 0.0
# this is loss for epoch 745 : 5.651949405670166, 0.0
# this is loss for epoch 746 : 5.64394998550415, 0.0
# this is loss for epoch 747 : 5.6361284255981445, 0.0
# this is loss for epoch 748 : 5.628209590911865, 0.0
# this is loss for epoch 749 : 5.620247840881348, 0.0
# this is loss for epoch 750 : 5.61248779296875, 0.0
# this is loss for epoch 751 : 5.604597091674805, 0.0
# this is loss for epoch 752 : 5.596814155578613, 0.0
# this is loss for epoch 753 : 5.5889973640441895, 0.0
# this is loss for epoch 754 : 5.581161022186279, 0.0
# this is loss for epoch 755 : 5.573160171508789, 0.0
# this is loss for epoch 756 : 5.565127372741699, 0.0
# this is loss for epoch 757 : 5.557054042816162, 0.0
# this is loss for epoch 758 : 5.548528671264648, 0.0
# this is loss for epoch 759 : 5.539750576019287, 0.0
# this is loss for epoch 760 : 5.531381130218506, 0.0
# this is loss for epoch 761 : 5.524927616119385, 0.0
# this is loss for epoch 762 : 5.517422676086426, 0.0
# this is loss for epoch 763 : 5.509159088134766, 0.0
# this is loss for epoch 764 : 5.501522541046143, 0.0
# this is loss for epoch 765 : 5.4944539070129395, 0.0
# this is loss for epoch 766 : 5.4873762130737305, 0.0
# this is loss for epoch 767 : 5.479698181152344, 0.0
# this is loss for epoch 768 : 5.4717278480529785, 0.0
# this is loss for epoch 769 : 5.463790416717529, 0.0
# this is loss for epoch 770 : 5.456308841705322, 0.0
# this is loss for epoch 771 : 5.449215888977051, 0.0
# this is loss for epoch 772 : 5.44205904006958, 0.0
# this is loss for epoch 773 : 5.434816837310791, 0.0
# this is loss for epoch 774 : 5.427468776702881, 0.0
# this is loss for epoch 775 : 5.42022705078125, 0.0
# this is loss for epoch 776 : 5.413201808929443, 0.0
# this is loss for epoch 777 : 5.406217575073242, 0.0
# this is loss for epoch 778 : 5.399168491363525, 0.0
# this is loss for epoch 779 : 5.391892910003662, 0.0
# this is loss for epoch 780 : 5.384554862976074, 0.0
# this is loss for epoch 781 : 5.377361297607422, 0.0
# this is loss for epoch 782 : 5.37028694152832, 0.0
# this is loss for epoch 783 : 5.363219738006592, 0.0
# this is loss for epoch 784 : 5.356138229370117, 0.0
# this is loss for epoch 785 : 5.349147319793701, 0.0
# this is loss for epoch 786 : 5.342105388641357, 0.0
# this is loss for epoch 787 : 5.335171222686768, 0.0
# this is loss for epoch 788 : 5.328269004821777, 0.0
# this is loss for epoch 789 : 5.321323394775391, 0.0
# this is loss for epoch 790 : 5.314348220825195, 0.0
# this is loss for epoch 791 : 5.307322978973389, 0.0
# this is loss for epoch 792 : 5.300360202789307, 0.0
# this is loss for epoch 793 : 5.29341983795166, 0.0
# this is loss for epoch 794 : 5.286508560180664, 0.0
# this is loss for epoch 795 : 5.2795729637146, 0.0
# this is loss for epoch 796 : 5.2727274894714355, 0.0
# this is loss for epoch 797 : 5.26585578918457, 0.0
# this is loss for epoch 798 : 5.259064674377441, 0.0
# this is loss for epoch 799 : 5.2523040771484375, 0.0
# this is loss for epoch 800 : 5.245517730712891, 0.0
# this is loss for epoch 801 : 5.238717555999756, 0.0
# this is loss for epoch 802 : 5.231910228729248, 0.0
# this is loss for epoch 803 : 5.225146770477295, 0.0
# this is loss for epoch 804 : 5.218381404876709, 0.0
# this is loss for epoch 805 : 5.211593151092529, 0.0
# this is loss for epoch 806 : 5.204891204833984, 0.0
# this is loss for epoch 807 : 5.198119163513184, 0.0
# this is loss for epoch 808 : 5.191283702850342, 0.0
# this is loss for epoch 809 : 5.1843743324279785, 0.0
# this is loss for epoch 810 : 5.177496910095215, 0.0
# this is loss for epoch 811 : 5.170775413513184, 0.0
# this is loss for epoch 812 : 5.164288520812988, 0.0
# this is loss for epoch 813 : 5.157407283782959, 0.0
# this is loss for epoch 814 : 5.150933265686035, 0.0
# this is loss for epoch 815 : 5.144619464874268, 0.0
# this is loss for epoch 816 : 5.138003826141357, 0.0
# this is loss for epoch 817 : 5.131363868713379, 0.0
# this is loss for epoch 818 : 5.124860763549805, 0.0
# this is loss for epoch 819 : 5.118179798126221, 0.0
# this is loss for epoch 820 : 5.1114912033081055, 0.0
# this is loss for epoch 821 : 5.104822158813477, 0.0
# this is loss for epoch 822 : 5.098034381866455, 0.0
# this is loss for epoch 823 : 5.0911407470703125, 0.0
# this is loss for epoch 824 : 5.084227561950684, 0.0
# this is loss for epoch 825 : 5.077803611755371, 0.0
# this is loss for epoch 826 : 5.071099758148193, 0.0
# this is loss for epoch 827 : 5.06429386138916, 0.0
# this is loss for epoch 828 : 5.057740688323975, 0.0
# this is loss for epoch 829 : 5.051316738128662, 0.0
# this is loss for epoch 830 : 5.044711112976074, 0.0
# this is loss for epoch 831 : 5.038141250610352, 0.0
# this is loss for epoch 832 : 5.031573295593262, 0.0
# this is loss for epoch 833 : 5.025169849395752, 0.0
# this is loss for epoch 834 : 5.018821716308594, 0.0
# this is loss for epoch 835 : 5.012279033660889, 0.0
# this is loss for epoch 836 : 5.005837917327881, 0.0
# this is loss for epoch 837 : 4.999532222747803, 0.0
# this is loss for epoch 838 : 4.9931840896606445, 0.0
# this is loss for epoch 839 : 4.9867777824401855, 0.0
# this is loss for epoch 840 : 4.980381965637207, 0.0
# this is loss for epoch 841 : 4.974068641662598, 0.0
# this is loss for epoch 842 : 4.967683792114258, 0.0
# this is loss for epoch 843 : 4.961317539215088, 0.0
# this is loss for epoch 844 : 4.954916954040527, 0.0
# this is loss for epoch 845 : 4.9485321044921875, 0.0
# this is loss for epoch 846 : 4.941988468170166, 0.0
# this is loss for epoch 847 : 4.935628890991211, 0.0
# this is loss for epoch 848 : 4.929195404052734, 0.0
# this is loss for epoch 849 : 4.922774791717529, 0.0
# this is loss for epoch 850 : 4.9163923263549805, 0.0
# this is loss for epoch 851 : 4.910035610198975, 0.0
# this is loss for epoch 852 : 4.903794765472412, 0.0
# this is loss for epoch 853 : 4.897528648376465, 0.0
# this is loss for epoch 854 : 4.891224384307861, 0.0
# this is loss for epoch 855 : 4.885052680969238, 0.0
# this is loss for epoch 856 : 4.8788371086120605, 0.0
# this is loss for epoch 857 : 4.872555255889893, 0.0
# this is loss for epoch 858 : 4.866310119628906, 0.0
# this is loss for epoch 859 : 4.860156536102295, 0.0
# this is loss for epoch 860 : 4.854068756103516, 0.0
# this is loss for epoch 861 : 4.848172187805176, 0.0
# this is loss for epoch 862 : 4.842194557189941, 0.0
# this is loss for epoch 863 : 4.836032867431641, 0.0
# this is loss for epoch 864 : 4.829887866973877, 0.0
# this is loss for epoch 865 : 4.823969841003418, 0.0
# this is loss for epoch 866 : 4.8180155754089355, 0.0
# this is loss for epoch 867 : 4.811997413635254, 0.0
# this is loss for epoch 868 : 4.805936336517334, 0.0
# this is loss for epoch 869 : 4.799874782562256, 0.0
# this is loss for epoch 870 : 4.793791770935059, 0.0
# this is loss for epoch 871 : 4.7877197265625, 0.0
# this is loss for epoch 872 : 4.781726360321045, 0.0
# this is loss for epoch 873 : 4.775771617889404, 0.0
# this is loss for epoch 874 : 4.769838809967041, 0.0
# this is loss for epoch 875 : 4.763989448547363, 0.0
# this is loss for epoch 876 : 4.758118629455566, 0.0
# this is loss for epoch 877 : 4.752257347106934, 0.0
# this is loss for epoch 878 : 4.746460914611816, 0.0
# this is loss for epoch 879 : 4.740665435791016, 0.0
# this is loss for epoch 880 : 4.734862804412842, 0.0
# this is loss for epoch 881 : 4.729075908660889, 0.0
# this is loss for epoch 882 : 4.723238945007324, 0.0
# this is loss for epoch 883 : 4.71745491027832, 0.0
# this is loss for epoch 884 : 4.711635589599609, 0.0
# this is loss for epoch 885 : 4.705836772918701, 0.0
# this is loss for epoch 886 : 4.7000908851623535, 0.0
# this is loss for epoch 887 : 4.694421291351318, 0.0
# this is loss for epoch 888 : 4.688661098480225, 0.0
# this is loss for epoch 889 : 4.682927131652832, 0.0
# this is loss for epoch 890 : 4.677178382873535, 0.0
# this is loss for epoch 891 : 4.671363353729248, 0.0
# this is loss for epoch 892 : 4.665567398071289, 0.0
# this is loss for epoch 893 : 4.659815788269043, 0.0
# this is loss for epoch 894 : 4.6543378829956055, 0.0
# this is loss for epoch 895 : 4.648695468902588, 0.0
# this is loss for epoch 896 : 4.6429762840271, 0.0
# this is loss for epoch 897 : 4.637328624725342, 0.0
# this is loss for epoch 898 : 4.631770610809326, 0.0
# this is loss for epoch 899 : 4.6262125968933105, 0.0
# this is loss for epoch 900 : 4.620582103729248, 0.0
# ...
# this is loss for epoch 5394 : 0.168452188372612, 0.0
# this is loss for epoch 5395 : 0.16893498599529266, 0.0
# this is loss for epoch 5396 : 0.16977939009666443, 0.0
# this is loss for epoch 5397 : 0.1712007075548172, 0.0
# this is loss for epoch 5398 : 0.17337177693843842, 0.0
# this is loss for epoch 5399 : 0.17650265991687775, 0.0
# this is loss for epoch 5400 : 0.1808013916015625, 0.0
# this is loss for epoch 5401 : 0.18655119836330414, 0.0
# this is loss for epoch 5402 : 0.1935102790594101, 0.0
# this is loss for epoch 5403 : 0.2009066641330719, 0.0
# this is loss for epoch 5404 : 0.20606987178325653, 0.0
# this is loss for epoch 5405 : 0.2060578316450119, 0.0
# this is loss for epoch 5406 : 0.19842547178268433, 0.0
# this is loss for epoch 5407 : 0.1855618804693222, 0.0
# this is loss for epoch 5408 : 0.17350813746452332, 0.0
# this is loss for epoch 5409 : 0.1680847704410553, 0.0
# this is loss for epoch 5410 : 0.1703013777732849, 0.0
# this is loss for epoch 5411 : 0.17631472647190094, 0.0
# this is loss for epoch 5412 : 0.18066638708114624, 0.0
# this is loss for epoch 5413 : 0.179814875125885, 0.0
# this is loss for epoch 5414 : 0.1746210902929306, 0.0
# this is loss for epoch 5415 : 0.1689480096101761, 0.0
# this is loss for epoch 5416 : 0.16649405658245087, 0.0
# this is loss for epoch 5417 : 0.16778935492038727, 0.0
# this is loss for epoch 5418 : 0.1705242395401001, 0.0
# this is loss for epoch 5419 : 0.1719031184911728, 0.0
# this is loss for epoch 5420 : 0.17070718109607697, 0.0
# this is loss for epoch 5421 : 0.16806276142597198, 0.0
# this is loss for epoch 5422 : 0.16599102318286896, 0.0
# this is loss for epoch 5423 : 0.16568289697170258, 0.0
# this is loss for epoch 5424 : 0.166696235537529, 0.0
# this is loss for epoch 5425 : 0.16764666140079498, 0.0
# this is loss for epoch 5426 : 0.1675303876399994, 0.0
# this is loss for epoch 5427 : 0.16642698645591736, 0.0
# this is loss for epoch 5428 : 0.16518737375736237, 0.0
# this is loss for epoch 5429 : 0.16458198428153992, 0.0
# this is loss for epoch 5430 : 0.16471199691295624, 0.0
# this is loss for epoch 5431 : 0.16517892479896545, 0.0
# this is loss for epoch 5432 : 0.16544878482818604, 0.0
# this is loss for epoch 5433 : 0.1651734560728073, 0.0
# this is loss for epoch 5434 : 0.1645372062921524, 0.0
# this is loss for epoch 5435 : 0.1639716625213623, 0.0
# this is loss for epoch 5436 : 0.1637478768825531, 0.0
# this is loss for epoch 5437 : 0.16382479667663574, 0.0
# this is loss for epoch 5438 : 0.1639774590730667, 0.0
# this is loss for epoch 5439 : 0.16400299966335297, 0.0
# this is loss for epoch 5440 : 0.16378460824489594, 0.0
# this is loss for epoch 5441 : 0.16342981159687042, 0.0
# this is loss for epoch 5442 : 0.16314317286014557, 0.0
# this is loss for epoch 5443 : 0.16300950944423676, 0.0
# this is loss for epoch 5444 : 0.16300861537456512, 0.0
# this is loss for epoch 5445 : 0.16303697228431702, 0.0
# this is loss for epoch 5446 : 0.16300010681152344, 0.0
# this is loss for epoch 5447 : 0.16286718845367432, 0.0
# this is loss for epoch 5448 : 0.1626625508069992, 0.0
# this is loss for epoch 5449 : 0.16247966885566711, 0.0
# this is loss for epoch 5450 : 0.16236422955989838, 0.0
# this is loss for epoch 5451 : 0.16232965886592865, 0.0
# this is loss for epoch 5452 : 0.16232295334339142, 0.0
# this is loss for epoch 5453 : 0.16225595772266388, 0.0
# this is loss for epoch 5454 : 0.16216684877872467, 0.0
# this is loss for epoch 5455 : 0.16204147040843964, 0.0
# this is loss for epoch 5456 : 0.1618977040052414, 0.0
# this is loss for epoch 5457 : 0.16179850697517395, 0.0
# this is loss for epoch 5458 : 0.16171956062316895, 0.0
# this is loss for epoch 5459 : 0.16165791451931, 0.0
# this is loss for epoch 5460 : 0.16161364316940308, 0.0
# this is loss for epoch 5461 : 0.16154174506664276, 0.0
# this is loss for epoch 5462 : 0.1614464968442917, 0.0
# this is loss for epoch 5463 : 0.16136720776557922, 0.0
# this is loss for epoch 5464 : 0.16127413511276245, 0.0
# this is loss for epoch 5465 : 0.16119542717933655, 0.0
# this is loss for epoch 5466 : 0.16113094985485077, 0.0
# this is loss for epoch 5467 : 0.16106081008911133, 0.0
# this is loss for epoch 5468 : 0.16100606322288513, 0.0
# this is loss for epoch 5469 : 0.16093412041664124, 0.0
# this is loss for epoch 5470 : 0.16086415946483612, 0.0
# this is loss for epoch 5471 : 0.1607910692691803, 0.0
# this is loss for epoch 5472 : 0.16071876883506775, 0.0
# this is loss for epoch 5473 : 0.16066835820674896, 0.0
# this is loss for epoch 5474 : 0.16062745451927185, 0.0
# this is loss for epoch 5475 : 0.1606290191411972, 0.0
# this is loss for epoch 5476 : 0.16064278781414032, 0.0
# this is loss for epoch 5477 : 0.1606760174036026, 0.0
# this is loss for epoch 5478 : 0.16065196692943573, 0.0
# this is loss for epoch 5479 : 0.1605776995420456, 0.0
# this is loss for epoch 5480 : 0.16049376130104065, 0.0
# this is loss for epoch 5481 : 0.16050569713115692, 0.0
# this is loss for epoch 5482 : 0.16063161194324493, 0.0
# this is loss for epoch 5483 : 0.1608135849237442, 0.0
# this is loss for epoch 5484 : 0.1609961837530136, 0.0
# this is loss for epoch 5485 : 0.1612430214881897, 0.0
# this is loss for epoch 5486 : 0.16160163283348083, 0.0
# this is loss for epoch 5487 : 0.16202311217784882, 0.0
# this is loss for epoch 5488 : 0.16241972148418427, 0.0
# this is loss for epoch 5489 : 0.16283836960792542, 0.0
# this is loss for epoch 5490 : 0.1632183939218521, 0.0
# this is loss for epoch 5491 : 0.16346342861652374, 0.0
# this is loss for epoch 5492 : 0.1634495109319687, 0.0
# this is loss for epoch 5493 : 0.16321150958538055, 0.0
# this is loss for epoch 5494 : 0.16276328265666962, 0.0
# this is loss for epoch 5495 : 0.16218559443950653, 0.0
# this is loss for epoch 5496 : 0.16154778003692627, 0.0
# this is loss for epoch 5497 : 0.16097500920295715, 0.0
# this is loss for epoch 5498 : 0.16061320900917053, 0.0
# this is loss for epoch 5499 : 0.16042548418045044, 0.0
# this is loss for epoch 5500 : 0.16024087369441986, 0.0
# this is loss for epoch 5501 : 0.1598491221666336, 0.0
# this is loss for epoch 5502 : 0.15941207110881805, 0.0
# this is loss for epoch 5503 : 0.15937648713588715, 0.0
# this is loss for epoch 5504 : 0.15975558757781982, 0.0
# this is loss for epoch 5505 : 0.15969736874103546, 0.0
# this is loss for epoch 5506 : 0.15961439907550812, 0.0
# this is loss for epoch 5507 : 0.1593044251203537, 0.0
# this is loss for epoch 5508 : 0.15873989462852478, 0.0
# this is loss for epoch 5509 : 0.15864431858062744, 0.0
# this is loss for epoch 5510 : 0.1583690345287323, 0.0
# this is loss for epoch 5511 : 0.1582677662372589, 0.0
# this is loss for epoch 5512 : 0.1580512523651123, 0.0
# this is loss for epoch 5513 : 0.15787500143051147, 0.0
# this is loss for epoch 5514 : 0.15771017968654633, 0.0
# this is loss for epoch 5515 : 0.15766434371471405, 0.0
# this is loss for epoch 5516 : 0.15767259895801544, 0.0
# this is loss for epoch 5517 : 0.15757624804973602, 0.0
# this is loss for epoch 5518 : 0.15746931731700897, 0.0
# this is loss for epoch 5519 : 0.1573219746351242, 0.0
# this is loss for epoch 5520 : 0.15723514556884766, 0.0
# this is loss for epoch 5521 : 0.15713118016719818, 0.0
# this is loss for epoch 5522 : 0.1570454239845276, 0.0
# this is loss for epoch 5523 : 0.1569097489118576, 0.0
# this is loss for epoch 5524 : 0.15681640803813934, 0.0
# this is loss for epoch 5525 : 0.1567596197128296, 0.0
# this is loss for epoch 5526 : 0.15666747093200684, 0.0
# this is loss for epoch 5527 : 0.15655246376991272, 0.0
# this is loss for epoch 5528 : 0.15646764636039734, 0.0
# this is loss for epoch 5529 : 0.1564207375049591, 0.0
# this is loss for epoch 5530 : 0.1563417911529541, 0.0
# this is loss for epoch 5531 : 0.15626496076583862, 0.0
# this is loss for epoch 5532 : 0.15621022880077362, 0.0
# this is loss for epoch 5533 : 0.15612559020519257, 0.0
# this is loss for epoch 5534 : 0.1560349315404892, 0.0
# this is loss for epoch 5535 : 0.15595829486846924, 0.0
# this is loss for epoch 5536 : 0.15589992702007294, 0.0
# this is loss for epoch 5537 : 0.15583983063697815, 0.0
# this is loss for epoch 5538 : 0.15579700469970703, 0.0
# this is loss for epoch 5539 : 0.1557883322238922, 0.0
# this is loss for epoch 5540 : 0.15577749907970428, 0.0
# this is loss for epoch 5541 : 0.1557789295911789, 0.0
# this is loss for epoch 5542 : 0.15582863986492157, 0.0
# this is loss for epoch 5543 : 0.15593646466732025, 0.0
# this is loss for epoch 5544 : 0.15611307322978973, 0.0
# this is loss for epoch 5545 : 0.1563730090856552, 0.0
# this is loss for epoch 5546 : 0.15675263106822968, 0.0
# this is loss for epoch 5547 : 0.1572977602481842, 0.0
# this is loss for epoch 5548 : 0.15805284678936005, 0.0
# this is loss for epoch 5549 : 0.15905265510082245, 0.0
# this is loss for epoch 5550 : 0.16032405197620392, 0.0
# this is loss for epoch 5551 : 0.16191083192825317, 0.0
# this is loss for epoch 5552 : 0.16380934417247772, 0.0
# this is loss for epoch 5553 : 0.1659674048423767, 0.0
# this is loss for epoch 5554 : 0.16823779046535492, 0.0
# this is loss for epoch 5555 : 0.17027421295642853, 0.0
# this is loss for epoch 5556 : 0.1716577559709549, 0.0
# this is loss for epoch 5557 : 0.17177143692970276, 0.0
# this is loss for epoch 5558 : 0.17033949494361877, 0.0
# this is loss for epoch 5559 : 0.16730429232120514, 0.0
# this is loss for epoch 5560 : 0.16332612931728363, 0.0
# this is loss for epoch 5561 : 0.15936200320720673, 0.0
# this is loss for epoch 5562 : 0.15642622113227844, 0.0
# this is loss for epoch 5563 : 0.15505102276802063, 0.0
# this is loss for epoch 5564 : 0.15517637133598328, 0.0
# this is loss for epoch 5565 : 0.15629112720489502, 0.0
# this is loss for epoch 5566 : 0.1576739400625229, 0.0
# this is loss for epoch 5567 : 0.158675417304039, 0.0
# this is loss for epoch 5568 : 0.15884384512901306, 0.0
# this is loss for epoch 5569 : 0.15816648304462433, 0.0
# this is loss for epoch 5570 : 0.1569076031446457, 0.0
# this is loss for epoch 5571 : 0.15554200112819672, 0.0
# this is loss for epoch 5572 : 0.15445521473884583, 0.0
# this is loss for epoch 5573 : 0.15385417640209198, 0.0
# this is loss for epoch 5574 : 0.15373791754245758, 0.0
# this is loss for epoch 5575 : 0.15396051108837128, 0.0
# this is loss for epoch 5576 : 0.15431438386440277, 0.0
# this is loss for epoch 5577 : 0.15459579229354858, 0.0
# this is loss for epoch 5578 : 0.15467020869255066, 0.0
# this is loss for epoch 5579 : 0.1544947475194931, 0.0
# this is loss for epoch 5580 : 0.1541183590888977, 0.0
# this is loss for epoch 5581 : 0.15364490449428558, 0.0
# this is loss for epoch 5582 : 0.15318790078163147, 0.0
# this is loss for epoch 5583 : 0.1528359204530716, 0.0
# this is loss for epoch 5584 : 0.1526252031326294, 0.0
# this is loss for epoch 5585 : 0.15254998207092285, 0.0
# this is loss for epoch 5586 : 0.15257222950458527, 0.0
# this is loss for epoch 5587 : 0.15263982117176056, 0.0
# this is loss for epoch 5588 : 0.15269705653190613, 0.0
# this is loss for epoch 5589 : 0.15270185470581055, 0.0
# this is loss for epoch 5590 : 0.1526346504688263, 0.0
# this is loss for epoch 5591 : 0.15250034630298615, 0.0
# this is loss for epoch 5592 : 0.15232092142105103, 0.0
# this is loss for epoch 5593 : 0.1521257609128952, 0.0
# this is loss for epoch 5594 : 0.15194164216518402, 0.0
# this is loss for epoch 5595 : 0.15178711712360382, 0.0
# this is loss for epoch 5596 : 0.15167057514190674, 0.0
# this is loss for epoch 5597 : 0.15159158408641815, 0.0
# this is loss for epoch 5598 : 0.15154339373111725, 0.0
# this is loss for epoch 5599 : 0.15151548385620117, 0.0
# this is loss for epoch 5600 : 0.1514964997768402, 0.0
# this is loss for epoch 5601 : 0.1514795869588852, 0.0
# this is loss for epoch 5602 : 0.15146557986736298, 0.0
# this is loss for epoch 5603 : 0.15144455432891846, 0.0
# this is loss for epoch 5604 : 0.15142977237701416, 0.0
# this is loss for epoch 5605 : 0.15142959356307983, 0.0
# this is loss for epoch 5606 : 0.1514519453048706, 0.0
# this is loss for epoch 5607 : 0.1515161097049713, 0.0
# this is loss for epoch 5608 : 0.15163694322109222, 0.0
# this is loss for epoch 5609 : 0.15183523297309875, 0.0
# this is loss for epoch 5610 : 0.15213754773139954, 0.0
# this is loss for epoch 5611 : 0.15257754921913147, 0.0
# this is loss for epoch 5612 : 0.1531684398651123, 0.0
# this is loss for epoch 5613 : 0.15395110845565796, 0.0
# this is loss for epoch 5614 : 0.15487022697925568, 0.0
# this is loss for epoch 5615 : 0.15590935945510864, 0.0
# this is loss for epoch 5616 : 0.15686623752117157, 0.0
# this is loss for epoch 5617 : 0.15762178599834442, 0.0
# this is loss for epoch 5618 : 0.15782921016216278, 0.0
# this is loss for epoch 5619 : 0.15743562579154968, 0.0
# this is loss for epoch 5620 : 0.15630310773849487, 0.0
# this is loss for epoch 5621 : 0.15474839508533478, 0.0
# this is loss for epoch 5622 : 0.15310591459274292, 0.0
# this is loss for epoch 5623 : 0.15178707242012024, 0.0
# this is loss for epoch 5624 : 0.1509932279586792, 0.0
# this is loss for epoch 5625 : 0.1507623940706253, 0.0
# this is loss for epoch 5626 : 0.1509215384721756, 0.0
# this is loss for epoch 5627 : 0.15123669803142548, 0.0
# this is loss for epoch 5628 : 0.15152764320373535, 0.0
# this is loss for epoch 5629 : 0.15165650844573975, 0.0
# this is loss for epoch 5630 : 0.15157531201839447, 0.0
# this is loss for epoch 5631 : 0.1512944996356964, 0.0
# this is loss for epoch 5632 : 0.15091949701309204, 0.0
# this is loss for epoch 5633 : 0.15055201947689056, 0.0
# this is loss for epoch 5634 : 0.15030452609062195, 0.0
# this is loss for epoch 5635 : 0.1502138376235962, 0.0
# this is loss for epoch 5636 : 0.15026067197322845, 0.0
# this is loss for epoch 5637 : 0.15039698779582977, 0.0
# this is loss for epoch 5638 : 0.15056614577770233, 0.0
# this is loss for epoch 5639 : 0.1507420837879181, 0.0
# this is loss for epoch 5640 : 0.1509096473455429, 0.0
# this is loss for epoch 5641 : 0.1511082798242569, 0.0
# this is loss for epoch 5642 : 0.15133027732372284, 0.0
# this is loss for epoch 5643 : 0.15162433683872223, 0.0
# this is loss for epoch 5644 : 0.1519814133644104, 0.0
# this is loss for epoch 5645 : 0.15243062376976013, 0.0
# this is loss for epoch 5646 : 0.1529362052679062, 0.0
# this is loss for epoch 5647 : 0.1535048633813858, 0.0
# this is loss for epoch 5648 : 0.15408384799957275, 0.0
# this is loss for epoch 5649 : 0.15462437272071838, 0.0
# this is loss for epoch 5650 : 0.15504024922847748, 0.0
# this is loss for epoch 5651 : 0.15524256229400635, 0.0
# this is loss for epoch 5652 : 0.1551440954208374, 0.0
# this is loss for epoch 5653 : 0.15470628440380096, 0.0
# this is loss for epoch 5654 : 0.15393273532390594, 0.0
# this is loss for epoch 5655 : 0.15288469195365906, 0.0
# this is loss for epoch 5656 : 0.15166477859020233, 0.0
# this is loss for epoch 5657 : 0.15042182803153992, 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18599/156675893.py in <module>
#     140             # bp()
#     141         # bp()
# --> 142         (loss + loss2).backward()
#     143         # print("this is loss for epoch {} : {} ".format(i,loss.detach().cpu().numpy()))
#     144         print("this is loss for epoch {} : {}, {} ".format(i,loss / F, loss2/F))
#
# ~/miniconda3/envs/lietorch/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~/miniconda3/envs/lietorch/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %%
if __name__ == '__main__':
    seed = 2000
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    points_info,normals_info,face_info = read_obj('frame_000001.obj')
    old_ones = np.ones((points_info.shape[0],1))

    points_info = np.concatenate((points_info,old_ones),axis=1)

    old_info = points_info
    
    all_info_list = []
    for i in range(80,90):
        path = "frame_0000{}.obj".format(i+1)

        tmp_target = read_obj(path)[0]
        target_ones = np.ones((tmp_target.shape[0],1))
        tmp_target_new = np.concatenate((tmp_target,target_ones),axis=1)
        all_info_list.append(tmp_target_new)

    all_info = np.stack(all_info_list)
    old_info = points_info
    target_info = all_info
    # W,R= train(old_info=points_info,target_info=all_info)
#     bp()
    N = points_info.shape[0]
    F = target_info.shape[0]
    B = 40  ### 这个肯定可以通过读pkl得到

    center, indexes = kmeans_plusplus(old_info[:, :-1], n_clusters=B, random_state=0)
    old_mesh = torch.tensor(old_info).float().cuda().detach()
    # bp()
    # ones = torch.ones(old_mesh.shape[0], 1).cuda()
    # x = torch.cat([old_mesh, ones], dim=1)

    center_t = torch.tensor(center).repeat(F, 1, 1).cuda()
    target_mesh = torch.tensor(target_info, requires_grad=False).float().cuda().detach()

    
    
    p1 = torch.randn((F, B, 7), requires_grad=True, device="cuda")

#     W1 = FF.softmax(W * 10).clone().detach()
#     W1 = (W1 / (W1.sum(1, keepdim=True).detach()))

    optimizer = optim.Adam([p1],lr=1e-2)
    chamLoss = chamfer3D.dist_chamfer_3D.chamfer_3DDist()
#     W = torch.tensor(W)
    
#     W1 = np.load('weight.npy')
    W1 = torch.tensor(W1).cuda()
    la_loss = LaplacianLoss(torch.tensor(points_info),torch.tensor(face_info-1),average=True)
    
    for i in range(10000):
        if i == 400:
            optimizer = optim.Adam([p1],lr=1e-3)
        optimizer.zero_grad()
        loss = 0
        f_idxs = random.sample(range(F), F)
        
        for f in f_idxs:
            T = torch.randn(B, 4, 4)

            for b in range(B):
                # R = SO3.InitFromVec(p1[f, b])
                # bp()
                # bp()
                # with torch.no_grad():
                # temp = torch.cat([p1[f, b], dist[f][:-1]])
                R = SE3.InitFromVec(p1[f, b])
                # bp()
                T[b] = R.matrix()
            T = T.cuda()     
        
            x = old_mesh
        
        
            bx = (T@x.T).permute(2, 0, 1)
            wbx = W1.unsqueeze(2) * bx
            # bp()
            wbx =  wbx.permute((1,0,2))40
            # print("Wbx", wbx.shape)
            # wbx = wbx.sum(0, keepdim=True)[:, :, :-1]
            wbx = wbx.sum(0, keepdim=True)
            # loss_init = chamLoss(target_mesh[f][None],wbx)
            # loss += loss_init[0].sum()
#             bp()
            loss += torch.sum((target_mesh[f]-wbx)**2) 
#             print(loss)
        # bp()
        loss.backward()
        # print("this is loss for epoch {} : {} ".format(i,loss.detach().cpu().numpy()))
        print("this is loss for epoch {} : {} ".format(i,loss / F))
        # print("p1: ", p1)
        optimizer.step()


    new_R = SE3.InitFromVec(p1)
    R = new_R.matrix()

    # W1 = (W - W.min()) / (W.max() - W.min())
    # W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
    # bp()
    # return R.detach(), W1.detach()

# %%
la_loss = LaplacianLoss(points_info,points_face-1,average=True)

# %%
la_loss(torch.tensor(wbx_result[-1][:, :-1]))
# Out:
# tensor(0.0052)

# %%
ccc = torch.tensor([[1,2,3],[4,5,6]])
ccc.size(0)
# Out:
# 2

# %%
points_info.shape
# Out:
# (3199, 4)

# %%
points_info,points_normal,points_face = read_obj('frame_000001.obj')
# all_info_list = []

# for i in range(1, 9):
#     path = "frame_00000{}.obj".format(i+1)
#     all_info_list.append(read_obj(path))

# %%
points_info.shape
# Out:
# (711, 3)

# %%
points_face.shape
# Out:
# (8726,)

# %%
R2 = R[:, :, :-1,:-1]
R2.shape
# Out:
# (8, 45, 3, 3)

# %%
import torch
W = torch.tensor(W).cuda()
# Out:
# /home/ivenwu/miniconda3/envs/lietorch/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
old_mesh = torch.tensor(points_info).float().cuda()
# W1 = (W - W.min()) / (W.max() - W.min())
W1 = FF.softmax(W)
W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
W1.shape
# Out:
# /home/ivenwu/miniconda3/envs/lietorch/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   This is separate from the ipykernel package so we can avoid doing imports until
# torch.Size([8315, 45])

# %%
R = torch.tensor(R).cuda()

# %%
(W1.unsqueeze(2) * (R[0]@old_mesh.T).permute(2, 0, 1)).permute(1, 0, 2).sum(0).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_30316/2019785926.py in <module>
# ----> 1 (W1.unsqueeze(2) * (R[0]@old_mesh.T).permute(2, 0, 1)).permute(1, 0, 2).sum(0).shape
#
# TypeError: unsupported operand type(s) for @: 'numpy.ndarray' and 'Tensor'

# %%
new_R = SE3.InitFromVec(p1)
R = new_R.matrix()

# %%
R1 = R.matrix()

# %%
R.shape
# Out:
# torch.Size([8, 30, 4, 4])

# %%
new_R = SE3.InitFromVec(p1)
R = new_R.matrix()
wbx_result = []
for r in R:
    bx = (r@old_mesh.T).permute(2, 0, 1)
    # W = W.unsqueeze(1)
    wbx = W1.unsqueeze(2) * bx

    wbx =  wbx.permute((1,0,2))
    wbx = wbx.sum(0).detach().cpu().numpy()
    wbx_result.append(wbx)

# %%
wbx_result0 = wbx_result

# %%
wbx = wbx_result.detach().cpu().numpy()[:, :-1]
wbx.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5191/840867176.py in <module>
# ----> 1 wbx = wbx_result.detach().cpu().numpy()[:, :-1]
#       2 wbx.shape
#
# AttributeError: 'list' object has no attribute 'detach'

# %%
W3.unsqueeze(2) * old_mesh.unsqueeze(1).repeat(1, 45, 1)for wbx_index,single_wbx in enumerate(wbx_result):
    # single_wbx = single_wbx.detach().cpu().numpy()
    print("this is index ",wbx_index)
    print(np.sum((all_info[wbx_index]-single_wbx)**2))
    # for gt in all_info:
    #     print(np.sum((gt-single_wbx)**2))
# Out:
# this is index  0
# 21.36908918353724
# this is index  1
# 128.30545293720138
# this is index  2
# 373.0977968274271
# this is index  3
# 771.560108692853
# this is index  4
# 1293.8557314639206
# this is index  5
# 1870.6729752832866
# this is index  6
# 2412.4298995824365
# this is index  7
# 2813.369257814287

# %%
W1 = W1.detach().cpu().numpy()

# %%
W1 = torch.tensor(W1)

# %%
color_list = []
number_list = [0,0.2,0.4,0.6,0.8,1]
for i in range(B):
    color = random.sample(number_list,3)
    color_list.append(color)

# %%
color_array = np.array(color_list)

# %%
color_array = np.array([[0.8, 0.4, 0.2],
       [0.6, 0.8, 1. ],
       [0.6, 0.2, 0.4],
       [1. , 0.6, 0.8],
       [0.2, 0.4, 0. ],
       [0.2, 0.4, 0.8],
       [0.4, 1. , 0.6],
       [1. , 0.4, 0. ],
       [0.6, 0.2, 0. ],
       [0.2, 1. , 0.4],
       [0.6, 0.2, 0.4],
       [0.6, 0.4, 0. ],
       [0.4, 0.6, 0.8],
       [0.8, 0. , 1. ],
       [0.4, 0.6, 0.2],
       [0.6, 1. , 0.2],
       [0. , 0.2, 0.4],
       [0.2, 0.8, 1. ],
       [0.4, 0.2, 1. ],
       [0.8, 0.4, 1. ],
       [0.8, 1. , 0. ],
       [1. , 0. , 0.6],
       [0.2, 1. , 0. ],
       [0.6, 0.2, 0.8],
       [1. , 0.6, 0.4],
       [0.4, 0. , 1. ],
       [0.2, 1. , 0.4],
       [0.2, 0.4, 0.8],
       [1. , 0. , 0.8],
       [1. , 0.8, 0.4]])

# %%
W_new = W1.clone()

# %%
W_new.sum()
# Out:
# tensor(3198.9993, device='cuda:0')

# %%
with torch.no_grad():
    for i in range(W1.shape[0]):
        max_idx = torch.topk(W1[i], 3)[1]
        for j in range(B):
            if j not in max_idx:
                W1[i, j] = 0
        W_new[i] = W1[i] / W1[i].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8854/1205028815.py in <module>
#       5             if j not in max_idx:
#       6                 W1[i, j] = 0
# ----> 7         W_new[i] = W1[i] / W1[i].sum()
#
# NameError: name 'W_new' is not defined

# %%
W_c = W_new.detach().cpu().numpy()

# %%
(W_c@color_array).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32427/2784454989.py in <module>
# ----> 1 (W_c@color_array).shape
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 30 is different from 40)

# %%
pcd_test = o3d.geometry.PointCloud()
pcd_test.points = o3d.utility.Vector3dVector(points_info)
# pcd_test.colors = o3d.utility.Vector3dVector(W_c@color_array)
pcd_test.normals = o3d.utility.Vector3dVector(points_normal)

# %%
distances = pcd_test.compute_nearest_neighbor_distance()
avg_dist = np.mean(distances)
radius = avg_dist

# %%
bpa_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
pcd_test,o3d.utility.DoubleVector([radius, radius * 2]))

# %%
bpa_mesh.triangles = o3d.utility.Vector3iVector(points_face-1)

# %%
np.array(bpa_mesh.triangles).shape
# Out:
# (8804, 3)

# %%
o3d.visualization.draw_geometries([bpa_mesh])

# %%
len(wbx_result)
# Out:
# 20

# %%
import open3d as o3d
pcd = o3d.geometry.PointCloud()
# pcd2 = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(wbx_result[-1][:, :-1])
# pcd.points = o3d.utility.Vector3dVector(points_info)
pcd.colors = o3d.utility.Vector3dVector(W_c@color_array)
# pcd.normals = o3d.utility.Vector3dVector(normals_info)
# pcd2.paint_uniform_color([0, 0, 1])
o3d.visualization.draw_geometries([pcd])

# %%
import open3d as o3d
pcd = o3d.geometry.PointCloud()
# pcd2 = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_info)
# pcd2.points = o3d.utility.Vector3dVector(eigvector_array)
pcd.colors = o3d.utility.Vector3dVector(W_c@color_array)
# pcd2.paint_uniform_color([0, 0, 1])
o3d.visualization.draw_geometries([pcd])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_8854/3042664672.py in <module>
#       2 pcd = o3d.geometry.PointCloud()
#       3 # pcd2 = o3d.geometry.PointCloud()
# ----> 4 pcd.points = o3d.utility.Vector3dVector(points_info)
#       5 # pcd2.points = o3d.utility.Vector3dVector(eigvector_array)
#       6 pcd.colors = o3d.utility.Vector3dVector(W_c@color_array)
#
# RuntimeError:

# %%
W3 = W1[:, -2]
# W2 = W3.detach().cpu().numpy()

# %%
onet = torch.zeros((8315, 2)).cuda()
# ff = torch.randn((8315,2)).cuda()
W2 = torch.cat([W3.unsqueeze(1), onet], dim=1)
W2.shape
# Out:
# torch.Size([8315, 3])

# %%
W2 = W2.detach().cpu().numpy()

# %%
W2.shape
# Out:
# (8315,)

# %%
import openmesh

# %%
mesh11 = openmesh.PolyMesh()
vv = []
for i in points_info:
    vv.append(mesh11.add_vertex(i))

# %%
for j in points_face:

    if len(j) ==3:
        mesh11.add_face([vv[j[0]-1],vv[j[1]-1],vv[j[2]-1]])
    elif len(j) ==4:
        mesh11.add_face([vv[j[0]-1],vv[j[1]-1],vv[j[2]-1],vv[j[3]-1]])

# %%
openmesh.write_mesh(mesh11, "bunny1111.obj")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5191/4196886075.py in <module>
# ----> 1 openmesh.write_mesh(mesh11, "bunny1111.obj")
#
# TypeError: write_mesh(): incompatible function arguments. The following argument types are supported:
#     1. (filename: str, mesh: openmesh.TriMesh, binary: bool = False, msb: bool = False, lsb: bool = False, swap: bool = False, vertex_normal: bool = False, vertex_color: bool = False, vertex_tex_coord: bool = False, halfedge_tex_coord: bool = False, edge_color: bool = False, face_normal: bool = False, face_color: bool = False, color_alpha: bool = False, color_float: bool = False) -> None
#     2. (filename: str, mesh: openmesh.PolyMesh, binary: bool = False, msb: bool = False, lsb: bool = False, swap: bool = False, vertex_normal: bool = False, vertex_color: bool = False, vertex_tex_coord: bool = False, halfedge_tex_coord: bool = False, edge_color: bool = False, face_normal: bool = False, face_color: bool = False, color_alpha: bool = False, color_float: bool = False) -> None
#
# Invoked with: <openmesh.PolyMesh object at 0x7f2207309f30>, 'bunny1111.obj'

# %%
points_face.max()
# Out:
# 8315

# %%
R[0, 0, :-1, :-1]@(R[0, 0, :-1, :-1].T)
# Out:
# tensor([[ 1.0000e+00, -1.5586e-08,  1.6673e-08],
#         [-1.5586e-08,  1.0000e+00, -2.3843e-08],
#         [ 1.6673e-08, -2.3843e-08,  1.0000e+00]], device='cuda:0',
#        grad_fn=<MmBackward>)

# %%
np.vstack([wbx_result[3][:, :-1], Bone_location[3]])
# Out:
# array([[ 0.60822886,  2.6521692 ,  0.7332895 ],
#        [ 0.63643765,  2.6594446 ,  0.63895345],
#        [ 0.66882116,  2.567572  ,  0.6456163 ],
#        ...,
#        [-0.85560316, -1.5839747 , -0.34642002],
#        [-0.56195986,  1.6341548 ,  1.198669  ],
#        [ 0.34078336, -0.55604595, -0.81593436]], dtype=float32)

# %%
Bone_location[3].shape
# Out:
# (45, 3)

# %%
wbx_result[3][:, :-1].shape
# Out:
# (8315, 3)

# %%
X = np.array([[1, 2], [1, 4], [1, 0],
...               [10, 2], [10, 4], [10, 0]])

# %%
X.shape
# Out:
# (6, 2)

# %%
center, indexes = kmeans_plusplus(old_mesh[:, :-1].detach().cpu().numpy(), n_clusters=10, random_state=0)

# %%
t
# Out:
# (45, 3)

# %%
np.save("R.npy", R.detach().cpu().numpy())

# %%
np.save("W.npy", W.detach().cpu().numpy())

# %%
W = np.load('W.npy')

# %%
R = np.load('R.npy')

# %%
R[0]
# Out:
# tensor([[[ 6.6551e-01,  5.5304e-01, -5.0125e-01,  7.7804e-01],
#          [-4.2060e-01,  8.3265e-01,  3.6026e-01, -3.1423e-01],
#          [ 6.1661e-01, -2.8933e-02,  7.8674e-01,  3.8223e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9372e-01, -1.0652e-01, -3.4407e-02,  1.7831e+00],
#          [ 1.1189e-01,  9.5393e-01,  2.7840e-01,  2.1400e-01],
#          [ 3.1677e-03, -2.8050e-01,  9.5985e-01, -5.5811e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[-5.4936e-02,  3.2795e-01, -9.4310e-01,  5.8502e-01],
#          [-4.7454e-01,  8.2246e-01,  3.1365e-01, -9.7908e-01],
#          [ 8.7852e-01,  4.6477e-01,  1.1044e-01,  2.0641e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 5.6366e-01,  6.3519e-01, -5.2803e-01, -5.1763e-01],
#          [-8.2434e-01,  4.7319e-01, -3.1073e-01,  6.6134e-01],
#          [ 5.2489e-02,  6.1043e-01,  7.9033e-01, -1.2407e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 7.7681e-01, -3.5558e-01,  5.1973e-01, -1.2656e+00],
#          [ 3.7012e-01,  9.2553e-01,  8.0025e-02,  3.2150e-01],
#          [-5.0948e-01,  1.3020e-01,  8.5057e-01,  1.2183e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.6660e-01,  2.3507e-01, -1.0216e-01, -6.7492e-01],
#          [-1.7811e-01,  9.0264e-01,  3.9181e-01,  1.9369e+00],
#          [ 1.8431e-01, -3.6052e-01,  9.1436e-01, -5.2655e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 8.9896e-01, -2.0257e-01,  3.8838e-01,  1.7789e+00],
#          [ 2.4328e-01,  9.6822e-01, -5.8104e-02,  1.3645e+00],
#          [-3.6426e-01,  1.4672e-01,  9.1967e-01,  5.8979e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 8.4397e-01,  5.7972e-02, -5.3325e-01,  1.6885e+00],
#          [ 8.6141e-02,  9.6659e-01,  2.4141e-01, -6.0826e-01],
#          [ 5.2943e-01, -2.4968e-01,  8.1078e-01, -2.8051e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.2537e-01,  2.4766e-01, -2.8698e-01, -1.7401e-01],
#          [-2.4137e-01,  9.6872e-01,  5.7679e-02,  9.6804e-01],
#          [ 2.9229e-01,  1.5896e-02,  9.5620e-01, -1.3263e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 5.5093e-01,  3.9342e-02,  8.3362e-01, -3.1969e-01],
#          [ 4.3725e-01,  8.3721e-01, -3.2848e-01,  8.5124e-01],
#          [-7.1084e-01,  5.4547e-01,  4.4404e-01,  1.1207e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 3.7434e-01,  9.2447e-01,  7.2305e-02,  4.8286e-01],
#          [-5.2425e-01,  2.7531e-01, -8.0583e-01,  1.2931e+00],
#          [-7.6487e-01,  2.6375e-01,  5.8772e-01,  4.5957e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 3.8854e-01,  8.8925e-01,  2.4141e-01, -9.0160e-01],
#          [-9.0744e-01,  4.1476e-01, -6.7296e-02,  1.0694e+00],
#          [-1.5997e-01, -1.9292e-01,  9.6809e-01, -1.0656e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 1.5536e-01, -2.0594e-01,  9.6615e-01, -1.8813e+00],
#          [ 7.8424e-01,  6.2042e-01,  6.1416e-03,  3.0330e-01],
#          [-6.0069e-01,  7.5675e-01,  2.5789e-01,  1.0863e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.4349e-01, -1.2764e-01,  3.0582e-01, -2.9280e-01],
#          [ 1.6071e-01,  9.8330e-01, -8.5407e-02,  1.8943e+00],
#          [-2.8981e-01,  1.2973e-01,  9.4825e-01, -2.0536e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.6407e-01,  2.0729e-01,  1.6615e-01,  2.4664e-01],
#          [-1.8704e-01,  9.7377e-01, -1.2959e-01, -1.0072e+00],
#          [-1.8866e-01,  9.3861e-02,  9.7755e-01,  2.7008e-02],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 2.5403e-01, -9.4290e-01,  2.1541e-01, -8.7354e-01],
#          [ 3.0247e-01,  2.8899e-01,  9.0829e-01,  6.6242e-01],
#          [-9.1869e-01, -1.6558e-01,  3.5861e-01,  6.1400e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.8367e-01, -4.9258e-02, -1.7311e-01, -7.2214e-01],
#          [ 1.3252e-01,  8.4904e-01,  5.1143e-01, -1.5496e+00],
#          [ 1.2178e-01, -5.2602e-01,  8.4171e-01, -5.2281e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9824e-01, -7.2869e-03,  5.8908e-02,  6.5592e-01],
#          [ 7.1866e-03,  9.9997e-01,  1.9137e-03,  1.3797e+00],
#          [-5.8921e-02, -1.4870e-03,  9.9826e-01,  5.1163e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.8219e-01, -9.4798e-02,  1.6222e-01, -9.2592e-01],
#          [ 1.8366e-01,  6.6648e-01, -7.2254e-01, -2.2719e-01],
#          [-3.9623e-02,  7.3947e-01,  6.7203e-01,  1.3585e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 7.8321e-01, -4.2211e-01, -4.5651e-01, -4.6558e-01],
#          [ 1.4702e-01,  8.3913e-01, -5.2368e-01,  1.0003e+00],
#          [ 6.0412e-01,  3.4304e-01,  7.1928e-01, -8.9368e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 5.4991e-02,  9.5197e-01, -3.0121e-01, -1.2092e+00],
#          [-9.9838e-01,  4.8058e-02, -3.0383e-02,  1.0641e+00],
#          [-1.4448e-02,  3.0239e-01,  9.5307e-01,  1.6906e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.2196e-01, -2.3463e-01,  3.0812e-01,  2.6716e-01],
#          [ 3.4431e-01,  8.6081e-01, -3.7477e-01, -1.1699e+00],
#          [-1.7731e-01,  4.5161e-01,  8.7442e-01, -2.7637e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[-3.9541e-01, -8.7100e-01,  2.9156e-01,  1.6318e+00],
#          [ 8.1353e-01, -4.7946e-01, -3.2906e-01, -1.0769e-01],
#          [ 4.2640e-01,  1.0708e-01,  8.9817e-01, -1.6352e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9407e-01,  4.4692e-02, -9.9162e-02,  4.1413e-01],
#          [-7.1606e-02,  9.5515e-01, -2.8734e-01,  2.2514e-01],
#          [ 8.1872e-02,  2.9274e-01,  9.5268e-01,  2.0296e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.4692e-01,  1.7685e-01,  2.6846e-01, -9.4751e-01],
#          [-1.3612e-01,  9.7710e-01, -1.6354e-01, -3.4916e-01],
#          [-2.9123e-01,  1.1831e-01,  9.4931e-01,  9.4282e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9342e-01,  1.1357e-01,  1.5066e-02, -1.2594e+00],
#          [-1.1101e-01,  9.2172e-01,  3.7164e-01, -1.1461e+00],
#          [ 2.8320e-02, -3.7086e-01,  9.2826e-01, -2.4004e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 7.8884e-01,  9.9247e-02, -6.0653e-01,  8.7797e-02],
#          [ 3.4365e-03,  9.8615e-01,  1.6583e-01,  2.1099e-01],
#          [ 6.1458e-01, -1.3290e-01,  7.7758e-01, -5.9753e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.5213e-01,  1.1002e-01,  2.8522e-01,  1.7260e-01],
#          [-1.1857e-01,  9.9286e-01,  1.2839e-02,  1.6968e+00],
#          [-2.8177e-01, -4.6043e-02,  9.5838e-01,  1.1597e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9117e-01,  1.1538e-01, -6.5324e-02,  9.2171e-02],
#          [-9.6278e-02,  9.6505e-01,  2.4373e-01,  1.6924e-01],
#          [ 9.1163e-02, -2.3529e-01,  9.6764e-01,  3.3434e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.3077e-01,  3.6309e-01,  4.2854e-02, -1.2028e-01],
#          [-3.1055e-01,  7.2328e-01,  6.1678e-01, -2.3026e-01],
#          [ 1.9295e-01, -5.8739e-01,  7.8597e-01, -4.6127e-02],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.8862e-01,  7.7940e-02,  1.2869e-01,  2.8935e-01],
#          [-1.0176e-01,  9.7642e-01,  1.9037e-01,  4.5099e-01],
#          [-1.1082e-01, -2.0130e-01,  9.7324e-01,  2.5375e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 2.1833e-01,  9.4669e-01,  2.3688e-01,  8.8545e-01],
#          [-6.3046e-01,  3.2211e-01, -7.0623e-01,  1.5689e+00],
#          [-7.4489e-01,  4.8511e-03,  6.6717e-01,  1.7809e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.9740e-01, -2.6468e-02, -6.7020e-02, -6.8976e-01],
#          [-9.3034e-03,  8.7501e-01, -4.8402e-01,  8.2319e-01],
#          [ 7.1454e-02,  4.8339e-01,  8.7249e-01,  1.5807e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.8303e-01,  1.2615e-01, -1.3319e-01,  1.4777e+00],
#          [-2.8250e-02,  8.2146e-01,  5.6956e-01, -4.9583e-01],
#          [ 1.8126e-01, -5.5613e-01,  8.1109e-01, -1.4516e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 8.5611e-01,  5.0174e-01, -1.2380e-01,  4.2580e-01],
#          [-4.5400e-01,  8.4465e-01,  2.8366e-01, -4.7950e-01],
#          [ 2.4689e-01, -1.8664e-01,  9.5090e-01, -1.4198e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 6.7347e-01,  6.3245e-01,  3.8269e-01, -8.5413e-01],
#          [-7.0222e-01,  7.0908e-01,  6.3921e-02,  9.6550e-01],
#          [-2.3093e-01, -3.1178e-01,  9.2166e-01, -8.8702e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[-2.6517e-01,  5.0341e-01,  8.2236e-01, -8.1465e-01],
#          [ 6.6103e-01,  7.1582e-01, -2.2504e-01,  3.0285e-02],
#          [-7.0195e-01,  4.8393e-01, -5.2258e-01,  3.2289e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 6.6527e-01, -7.1699e-01, -2.0819e-01,  9.8987e-01],
#          [ 6.9201e-01,  6.9684e-01, -1.8852e-01, -6.7987e-02],
#          [ 2.8024e-01, -1.8653e-02,  9.5975e-01, -1.1600e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 8.9819e-01, -1.9276e-01, -3.9509e-01,  1.2070e-01],
#          [ 3.8609e-01,  7.7564e-01,  4.9932e-01, -7.3930e-01],
#          [ 2.1019e-01, -6.0102e-01,  7.7110e-01,  7.1425e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 2.6310e-01, -9.6465e-01,  1.5221e-02, -8.2205e-01],
#          [ 9.5737e-01,  2.6300e-01,  1.1947e-01,  3.6236e-01],
#          [-1.1925e-01, -1.6861e-02,  9.9272e-01,  4.3681e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 2.1212e-01, -4.4247e-01,  8.7134e-01, -2.5965e+00],
#          [ 5.9158e-01,  7.6783e-01,  2.4589e-01,  2.1493e+00],
#          [-7.7784e-01,  4.6331e-01,  4.2463e-01,  6.4380e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 3.7936e-01, -2.1185e-01,  9.0067e-01, -2.2181e+00],
#          [ 3.8914e-01,  9.1969e-01,  5.2419e-02,  9.4298e-01],
#          [-8.3944e-01,  3.3060e-01,  4.3133e-01,  1.7836e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.2811e-01,  2.4032e-01,  2.8436e-01, -4.7806e-01],
#          [-2.6420e-03,  7.6801e-01, -6.4043e-01, -1.5733e-01],
#          [-3.7230e-01,  5.9364e-01,  7.1343e-01,  1.2954e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.7558e-01, -9.7829e-02, -1.9668e-01, -3.3001e-01],
#          [ 1.1744e-01,  9.8893e-01,  9.0648e-02,  2.2720e+00],
#          [ 1.8563e-01, -1.1153e-01,  9.7627e-01,  4.6859e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]],
#
#         [[ 9.5406e-01,  2.4050e-01, -1.7871e-01, -8.9745e-01],
#          [-2.7506e-01,  9.3951e-01, -2.0410e-01,  2.3149e-01],
#          [ 1.1881e-01,  2.4388e-01,  9.6250e-01, -8.2991e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        device='cuda:0')

# %%
R_tmp = R[0]

# %%
eigvector_list = []
for i in range(R_tmp.shape[0]):
    (evals,evecs) = torch.eig(torch.tensor(R_tmp[i]),eigenvectors=True)
#     print(i)
#     print(evals)
#     print(evecs)
    flag =  0
    for val_index in range(len(evals)):
        
        if torch.abs(evals[val_index][0]-1)<1e-5 and torch.abs(evals[val_index][1])<1e-5:

            scale_info = -100
            if torch.abs(evecs[val_index][0])+torch.abs(evecs[val_index][1])+torch.abs(evecs[val_index][2])>1e-4:
#                 print(evecs[val_index])
#                 vector_wanted = (evecs[val_index]/torch.abs(evecs[val_index][-1]))[:-1]
                vector_wanted = evecs[val_index][:-1]
#                 flag = 1
#                 if scale_info != -100:
#                     vector_wanted = vector_wanted/torch.abs(scale_info)
#                     eigvector_list.append(vector_wanted.cpu().detach().numpy())
#                     break
#             else:
#                 scale_info = evecs[val_index][-1]
#                 if flag==1:
#                     vector_wanted = vector_wanted/torch.abs(scale_info)
#                     eigvector_list.append(vector_wanted.cpu().detach().numpy())
#                     break
#                 eigvector_list.append(vector_wanted.cpu().detach().numpy())
#                 break
# Out:
# /home/ivenwu/miniconda3/envs/lietorch/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: torch.eig is deprecated in favor of torch.linalg.eig and will be removed in a future PyTorch release.
# torch.linalg.eig returns complex tensors of dtype cfloat or cdouble rather than real tensors mimicking complex tensors.
# L, _ = torch.eig(A)
# should be replaced with
# L_complex = torch.linalg.eigvals(A)
# and
# L, V = torch.eig(A, eigenvectors=True)
# should be replaced with
# L_complex, V_complex = torch.linalg.eig(A) (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448224956/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2897.)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
eigvector_list = []
for i in range(R_tmp.shape[0]):

    (evals,evecs) = torch.linalg.eig(R_tmp[i])
    for j in range(4):
        if torch.abs(evecs[j].real.max()) > 1e-5 and torch.abs(evecs[j].imag.max()) < 1e-5:
            eigvector_list.append(evecs[j])
    # print(evals, evecs)

# %%
eigvector_list
# Out:
# []

# %%
R_tmp[i].shape
# Out:
# torch.Size([4, 4])

# %%
eigvector_array = np.array(eigvector_list)

# %%
eigvector_array
# Out:
# array([[-2.08931750e+05, -9.44651125e+05,  1.12544150e+06],
#        [-3.24681225e+06, -1.43762031e+05,  8.98924188e+05],
#        [ 1.95427598e+04, -5.86003062e+05,  3.64042188e+05],
#        [-5.96894375e+05, -1.18165962e+06,  2.50963225e+06],
#        [-1.24324430e+05,  4.42932750e+06,  4.41323500e+06],
#        [ 1.31386288e+06, -3.10073656e+05, -5.37888375e+05],
#        [-1.26899762e+06,  9.39687400e+06,  7.66483850e+06],
#        [-9.65893750e+05,  0.00000000e+00,  3.28692266e+04],
#        [-2.63832363e+04, -5.67883438e+05,  6.76968875e+05],
#        [ 4.71411600e+06,  0.00000000e+00,  1.49484412e+06],
#        [ 9.45399625e+05, -1.65568438e+06,  2.87590175e+06],
#        [-5.24790875e+05,  1.72209975e+06,  1.08762620e+07],
#        [-8.25391094e+04,  3.47957688e+05,  2.88241406e+05],
#        [-1.15535425e+06,  7.71927500e+06,  5.02589250e+06],
#        [-9.30507812e+05, -2.15668350e+06,  3.12389625e+06],
#        [-2.89633725e+06, -4.90623450e+06,  6.42465350e+06],
#        [-8.08298650e+06, -9.63290750e+05, -1.64752312e+06],
#        [ 2.92674219e+04,  8.31555950e+06,  1.44393925e+06],
#        [-2.77627600e+06,  2.66241406e+05, -3.77330062e+05],
#        [ 7.28664250e+06,  0.00000000e+00,  4.28173800e+06],
#        [-4.35142219e+05, -5.17617719e+05,  4.24592400e+06],
#        [-9.34659500e+05,  3.17961750e+05, -5.13810844e+05],
#        [-5.15592219e+05,  1.72776500e+06,  9.40927800e+06],
#        [-2.23558475e+06,  3.02539625e+05,  5.02299156e+05],
#        [ 1.25983688e+06,  5.59919400e+06,  4.05355300e+06],
#        [-4.15642125e+06,  5.02174492e+04,  8.89088312e+05],
#        [ 1.06310238e+06,  0.00000000e+00, -1.14584500e+05],
#        [-2.37797125e+05,  6.15242350e+06,  3.49158500e+06],
#        [-1.90194438e+06, -4.01868625e+05, -6.20215375e+05],
#        [-1.10365738e+06, -8.48950547e+04, -4.39157750e+05],
#        [ 4.58805281e+05, -1.26987391e+05, -2.13043703e+05],
#        [ 5.78177000e+05,  1.00682181e+06,  2.13620150e+06],
#        [ 1.28120800e+06, -1.59121465e+04,  1.29697664e+05],
#        [-8.71960900e+06, -8.14515688e+05,  1.73726138e+06],
#        [-2.06972425e+06,  3.09868350e+06,  8.41076900e+06],
#        [-1.84705112e+06,  3.42714825e+06,  1.02133090e+07],
#        [ 7.85228594e+04,  0.00000000e+00,  1.04119785e+04],
#        [-1.60200801e+04, -4.90684258e+04,  1.98893734e+05],
#        [ 1.40588512e+06, -4.58220125e+05, -6.02139688e+05],
#        [-2.13344000e+05,  2.17366328e+05,  4.32314500e+06],
#        [-6.51071375e+05,  9.35442100e+06,  8.24355300e+06],
#        [-3.25663125e+05,  6.31103500e+06,  3.04792125e+06],
#        [-1.72779862e+06,  2.12339859e+05, -6.59835625e+05],
#        [-1.76740700e+06,  7.50004750e+06,  5.42418250e+06],
#        [-1.03313219e+05, -2.24781375e+05,  3.35404250e+05]], dtype=float32)

# %%
for k in range(eigvector_array.shape[0]):
    
    print(eigvector_array[k].max(),eigvector_array[k].min())
# Out:
# 1125441.5 -944651.1
# 898924.2 -3246812.2
# 364042.2 -586003.06
# 2509632.2 -1181659.6
# 4429327.5 -124324.43
# 1313862.9 -537888.4
# 9396874.0 -1268997.6
# 32869.227 -965893.75
# 676968.9 -567883.44
# 4714116.0 0.0
# 2875901.8 -1655684.4
# 10876262.0 -524790.9
# 347957.7 -82539.11
# 7719275.0 -1155354.2
# 3123896.2 -2156683.5
# 6424653.5 -4906234.5
# -963290.75 -8082986.5
# 8315559.5 29267.422
# 266241.4 -2776276.0
# 7286642.5 0.0
# 4245924.0 -517617.72
# 317961.75 -934659.5
# 9409278.0 -515592.22
# 502299.16 -2235584.8
# 5599194.0 1259836.9
# 889088.3 -4156421.2
# 1063102.4 -114584.5
# 6152423.5 -237797.12
# -401868.62 -1901944.4
# -84895.055 -1103657.4
# 458805.28 -213043.7
# 2136201.5 578177.0
# 1281208.0 -15912.146
# 1737261.4 -8719609.0
# 8410769.0 -2069724.2
# 10213309.0 -1847051.1
# 78522.86 0.0
# 198893.73 -49068.426
# 1405885.1 -602139.7
# 4323145.0 -213344.0
# 9354421.0 -651071.4
# 6311035.0 -325663.12
# 212339.86 -1727798.6
# 7500047.5 -1767407.0
# 335404.25 -224781.38

# %%
(evals,evecs) = torch.eig(R[0][1],eigenvectors=True)

# %%
evals
# Out:
# tensor([[ 1.0000,  0.0000],
#         [ 0.9537,  0.3006],
#         [ 0.9537, -0.3006],
#         [ 1.0000,  0.0000]], device='cuda:0')

# %%
evecs
# Out:
# tensor([[-9.2959e-01, -4.1160e-02,  2.5737e-01,  9.2959e-01],
#         [-6.2496e-02,  7.0572e-01,  0.0000e+00,  6.2496e-02],
#         [ 3.6326e-01,  1.6084e-02,  6.5861e-01, -3.6326e-01],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  2.8631e-07]], device='cuda:0')

# %%
R[0][0]
# Out:
# tensor([[ 0.6655,  0.5530, -0.5012,  0.7780],
#         [-0.4206,  0.8327,  0.3603, -0.3142],
#         [ 0.6166, -0.0289,  0.7867,  0.3822],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]], device='cuda:0')

# %%
for j in range(45):
    R[0]
# Out:
# torch.Size([8, 45, 4, 4])

# %%
def train(old_info,target_info, n_steps=1000, lr_init=0.2):
    """ Riemannian Gradient Descent """

    N = points_info.shape[0]
    F = target_info.shape[0]
    B = 45  ### 这个肯定可以通过读pkl得到


    old_mesh = torch.tensor(old_info).float().cuda().detach()
    
    # bp()
    # ones = torch.ones(old_mesh.shape[0], 1).cuda()
    # x = torch.cat([old_mesh, ones], dim=1)


    target_mesh = torch.tensor(target_info, requires_grad=False).float().cuda().detach()

    # bp()
    # W = torch.randint(10,(N,B))
    # W = torch.randn((N,B)).cuda()
    # W = np.random.randint(10,size=(N,B))
    # bp()
    # W = SO3(torch.from_numpy(W).float().cuda())
    # W = torch.zeros((N, B), dtype=torch.float, requires_grad=True, device="cuda")
    W = torch.randn((N, B), requires_grad=True, device="cuda")
    W2 = torch.randn((N, B), requires_grad=True, device="cuda")
    # W = torch.tensor(W0.float(), requires_grad=True, device="cuda")
    # W = W * 0
    # bp()
    # W = LieGroupParameter(W)
    # bp()
    # R = torch.randint(10,(B,3,3))laplacian = torch.zeros([self.nv, self.nv]).astype(np.float32)

    # bp()
    # random quaternion
    p1 = torch.randn((F, B, 7), requires_grad=True, device="cuda")
    # W = W.cuda()
    # p1 = p1.cuda()
    # p1 = p1 / p1.norm(dim=-1, keepdim=True)
    # create SO3 object from quaternion (differentiable w.r.t q)
    
    # 4x4 transformation matrix (differentiable w.r.t R)
    


    optimizer = optim.Adam([W, p1],lr=1e-3)
    chamLoss = chamfer3D.dist_chamfer_3D.chamfer_3DDist()
    for i in range(n_steps):

        optimizer.zero_grad()
        loss = 0
        f_idxs = random.sample(range(F), F)
        
        for f in f_idxs:
            T = torch.randn(B, 4, 4)
            for b in range(B):
                # R = SO3.InitFromVec(p1[f, b])
                R = SE3.InitFromVec(p1[f, b])
                # bp()
                T[b] = R.matrix()
            T = T.cuda()     
            # bp()      
            # bp() 
            # W1 = W
            # W1 = (W - W.min()) / (W.max() - W.min())
            W1 = FF.softmax(W*10)
            W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
            W2[W1 < 0.1] = 0
            
            # ones = torch.ones(old_mesh.shape[0], 1).cuda()
            # x = torch.cat([old_mesh, ones], dim=1)
            x = old_mesh
        
        
            bx = (T@x.T).permute(2, 0, 1)
            wbx = W1.unsqueeze(2) * bx
            # bp()
            wbx =  wbx.permute((1,0,2))
            # print("Wbx", wbx.shape)
            # wbx = wbx.sum(0, keepdim=True)[:, :, :-1]
            wbx = wbx.sum(0, keepdim=True)
            # loss_init = chamLoss(target_mesh[f][None],wbx)
            # loss += loss_init[0].sum()

            loss += torch.sum((target_mesh[f]-wbx)**2) + torch.sum(torch.abs(W))

#             loss.backward()
            print("loss",loss)
            # bp()
        # bp()
        loss.backward()
        # print("this is loss for epoch {} : {} ".format(i,loss.detach().cpu().numpy()))
        print("this is loss for epoch {} : {} ".format(i,loss / F))
        # print("p1: ", p1)
        optimizer.step()


    new_R = SE3.InitFromVec(p1)
    R = new_R.matrix()

    # W1 = (W - W.min()) / (W.max() - W.min())
    # W1 = (W1 / (W1.sum(1, keepdim=True).detach()))
    # bp()
    # return R.detach(), W1.detach()
    return W.detach(),R.detach()
